# %%
import networkx as nx
import numpy as np
from random import randrange, choice, random
import math

# %%
import json
from networkx.readwrite import json_graph

# %%
import pandas as pd
import vincent
vincent.initialize_notebook()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %% [markdown]
# # Generate graph

# %%
n = 8
m = 2
p = 0.3

# %%
G = nx.barbell_graph(4,0)

# %%
G = nx.scale_free_graph(n)

# %%
G = nx.powerlaw_cluster_graph(n=n, m=m, p=p)

# %%
G = nx.cycle_graph(10)

# %% [markdown]
# ### Save and Plot Graph

# %%
d = json_graph.node_link_data(G)
for node in d['nodes']:
    node['name']=node['id']
    node['value']=G.degree(node['id'])

d['adjacency'] = json_graph.adjacency_data(G)['adjacency']
json.dump(d, open('graph.json','w'))

# %%
# %%html
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>
# Out:
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>

# %% [markdown]
# ### Convert to DiGraph, if necessary

# %%
if G.is_multigraph():
    if G.is_directed():
        Gm = G.copy()
        G = nx.DiGraph()
        for (u,v) in Gm.edges_iter():
            G.add_edge(u,v)

# %% [markdown]
# # Simulate Random Walks

# %%
frogs = 1000

# %%
# Life expectancy L. L should be the mean of a geometric distribution
L = int(math.ceil(10*math.log(G.order())))

# %%
# P_die is the probability that a frog dies at any given time
P_die = 1/float(L)

# %% [markdown]
# # New development

# %%
def edgetokey(e):
    (u,v) = e
    return '(' + str(u) + ', ' + str(v) + ')'

# %%
def isexpensive(G,expensiveedges,e):
    if G.is_directed():
        return edgetokey(e) in expensiveedges
    else:
        (u,v) = e
        return edgetokey((u,v)) in expensiveedges or edgetokey((v,u)) in expensiveedges

# %%
def dictcounter(d, k, v=1):
    try:
        d[k] += v
    except:
        d[k] = v

# %%
def randomwalk(G, frogs, P_die):
    frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs).tolist()
    G.graph['teleportations'] = {}
    for node in G.nodes_iter():
        G.node[node]['visits'] = 0
        G.node[node]['deaths'] = 0
    # Initialize edge traversal counters
    for e in G.edges_iter():
        G.edge[e[0]][e[1]]['timeline'] = {}
    frogs_left = frogs
    time = 0
    G.graph['total_visits'] = 0
    G.graph['death_times_sum'] = 0

    while frogs_left:
        time +=1
        for f in range(frogs):
            curloc = frog_locations[f]

            # Skip dead frogs
            if curloc == None:
                continue

            # Flip coin to die
            if random() < P_die:
                G.node[curloc]['deaths'] += 1
                G.graph['death_times_sum'] += time
                frog_locations[f] = None
                frogs_left -= 1
                continue

            G.graph['total_visits'] +=1

            # Node has successors
            if len(G[curloc])>0:
                frog_locations[f] = choice(G[curloc].keys())
                loc = frog_locations[f]

                dictcounter(G.edge[curloc][loc]['timeline'], time)

            # Node does not have successors - Teleport
            else:
                frog_locations[f] = np.random.randint(0, high = G.number_of_nodes())
                dictcounter(G.graph['teleportations'],time)


            G.node[frog_locations[f]]['visits'] +=1

# %%
def plotrwresult(G):
    visits = [G.node[node]['visits'] for node in G.nodes_iter() ]
    norm_visits = np.array(visits)/float(G.graph['total_visits'])

    deaths = [G.node[node]['deaths'] for node in G.nodes_iter() ]
    norm_deaths = np.array(deaths)/float(sum(deaths))

    if G.is_directed():
        degrees = [ G.in_degree(node) for node in G.nodes_iter() ]
        norm_degrees = np.array(degrees)/float(G.size())
    else:
        degrees = [ G.degree(node) for node in G.nodes_iter() ]
        norm_degrees = np.array(degrees)/float(2*G.size())

    multi_iter1 = {'index':range(G.order()), 'Visits':norm_visits, 'Deaths':norm_deaths, 'Degree':norm_degrees}
    line = vincent.Scatter(multi_iter1, iter_idx='index')
    line.axis_titles(x='Vertex', y='Juice')
    line.legend(title='Results')
    line.width = 400
    line.height = 300
    line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=1)
    
    line.marks[0].marks[0].properties.update = vincent.PropertySet()
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)
    line.scales['shape'] = vincent.Scale(name='shape', type='ordinal',
                          domain=vincent.DataRef(data='table', field='data.col'),
                          range=["square", "circle", "triangle-down", "triangle-up"])
    line.marks[0].marks[0].properties.enter.shape = vincent.ValueRef(scale="shape", field="data.col")
    line.legends[0].shape = "shape" 
    
    return line

# %%
def plotrwtraversal(G, expensiveedges=[]):
    data = []
    index = []

    for e in G.edges_iter():
        key = edgetokey((e[0], e[1]))
        data.append(pd.Series(G.edge[e[0]][e[1]]['timeline']))
        index.append(key)
    
    df = pd.DataFrame(data, index=index).T
    
    if len(expensiveedges)>0:
        dfexp = df[expensiveedges].copy()
        dfcheap = df.copy()
        dfcheap.drop(expensiveedges, 1, inplace=True)

        dfexpcopy = dfexp.copy()
        dfexpcopy[dfexp>0] = 1
        cost = (dfexpcopy.sum(axis=1)).sum()

        datacost = []
        indexcost = []
        datacost.append(dfexp.sum(axis=1))
        indexcost.append('Expensive')
        datacost.append(dfcheap.sum(axis=1))
        indexcost.append('Cheap')
        
        dfcost = pd.DataFrame(datacost, index=indexcost).T
        
        finaldf = dfcost
    else:
        cost = 0
        finaldf = df

    #if len(G.graph['teleportations'])>0:
    finaldf['Teleportation'] = pd.Series(G.graph['teleportations'])
    
    try:
        if len(G.graph['waiting'])>0:
            finaldf['Waiting'] = pd.Series(G.graph['waiting'])
    except:
        pass
    
    line = vincent.StackedArea(finaldf)
    line.axis_titles(x='Time', y='# frogs')
    line.legend(title='Edge')
    line.width = 400
    line.height = 300
    line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=0.8)
   
    if len(expensiveedges)>0:
        line.colors(range_=['#ff0000','#50aa50','#6060aa', '#eeeeee'])

    
    line.marks[0].marks[0].properties.update = vincent.PropertySet()
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)

    line.marks[0].marks[0].properties.update.opacity = vincent.ValueRef(value=0.8)
    line.marks[0].marks[0].properties.hover.opacity = vincent.ValueRef(value=1)
        
    return line

# %%
def randomwalk2(G, frogs, P_die, T=10, expensiveedges = []):
    G.graph['teleportations'] = {}
    G.graph['waiting'] = {}
    for node in G.nodes_iter():
        G.node[node]['visits'] = 0
        G.node[node]['deaths'] = 0
        G.node[node]['frogs'] = 0
        G.node[node]['incomingfrogs'] = 0
    # Initialize edge traversal counters
    for e in G.edges_iter():
        G.edge[e[0]][e[1]]['timeline'] = {}
        if not G.is_directed():
            G.edge[e[0]][e[1]]['frogstosmall'] = 0
            G.edge[e[0]][e[1]]['frogstolarge'] = 0
        else:
            G.edge[e[0]][e[1]]['frogs'] = 0
        
    frogs_left = frogs
    time = 0
    G.graph['total_visits'] = 0
    G.graph['death_times_sum'] = 0
    
    frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs).tolist()
    for i in range(frogs):
        G.node[frog_locations[i]]['frogs'] += 1
    del frog_locations
    
    while frogs_left:
        time +=1
        
        # Deal with old node frogs
        for node in G.nodes_iter():
            if G.node[node]['frogs'] == 0:
                continue
            for f in range(G.node[node]['frogs']):
                # Flip coin to die
                if random() < P_die:
                    G.node[node]['deaths'] += 1
                    G.graph['death_times_sum'] += time
                    frogs_left -= 1
                    continue
                G.graph['total_visits'] +=1
                # Node has successors
                if len(G[node])>0:
                    loc = choice(G[node].keys())
                    if G.is_directed():
                        G.edge[node][loc]['frogs'] += 1
                    else:
                        if loc >= node:
                            G.edge[node][loc]['frogstolarge'] += 1
                        else:
                            G.edge[node][loc]['frogstosmall'] += 1
                # Node does not have successors - Teleport
                else:
                    loc = np.random.randint(0, high = G.number_of_nodes())
                    dictcounter(G.graph['teleportations'],time)
                    G.node[loc]['incomingfrogs'] += 1
                G.node[loc]['visits'] +=1
            G.node[node]['frogs'] = 0
            
        # Deal with edge frogs
        for (u,v) in G.edges_iter():
            # Don't process expensive edges unless time is multiple of T
            if isexpensive(G, expensiveedges, (u,v)) and not (time % T == ((u+v) % T)):
            #if isexpensive(G, expensiveedges, (u,v)) and not (time % T == 0):
                if G.is_directed():
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogs'])
                else:
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogstosmall'])
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogstolarge'])
                continue
            
            if G.is_directed():
                G.node[v]['incomingfrogs'] += G.edge[u][v]['frogs']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogs'])
                G.edge[u][v]['frogs'] = 0
            else:
                if v >= u:
                    large = v
                    small = u
                else:
                    large = u
                    small = v
                    
                G.node[large]['incomingfrogs'] += G.edge[u][v]['frogstolarge']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogstolarge'])
                G.edge[u][v]['frogstolarge'] = 0
                
                G.node[small]['incomingfrogs'] += G.edge[u][v]['frogstosmall']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogstosmall'])
                G.edge[u][v]['frogstosmall'] = 0
                
        # Deal with node incoming frogs
        for node in G.nodes_iter():
            G.node[node]['frogs'] += G.node[node]['incomingfrogs']
            G.node[node]['incomingfrogs'] = 0

    G.graph['endtime'] = time

# %%
def plotrwtraversal2(G, expensiveedges=[], time=None, countfrogs = False):
    data = []
    index = []

    for e in G.edges_iter():
        key = edgetokey((e[0], e[1]))
        sr = pd.Series(G.edge[e[0]][e[1]]['timeline'])
        if not countfrogs:
            sr[sr>0] = 1
        data.append(sr)
        index.append(key)
    
    if time:
        data.append(pd.Series(time*[0]))
        index.append('hack')
    
    df = pd.DataFrame(data, index=index).T
          
    if time:
        del df['hack']
        
    dfexp = df[expensiveedges].copy()
    dfcheap = df.copy()
    dfcheap.drop(expensiveedges, 1, inplace=True)
    
    dfexpcopy = dfexp.copy()
    dfexpcopy[dfexp>0] = 1
    cost = (dfexpcopy.sum(axis=1)).sum()
    
    G.graph['cost'] = cost
    
    if len(expensiveedges)>0:
        datacost = []
        indexcost = []
        datacost.append(dfexp.sum(axis=1))
        indexcost.append('Expensive')
        datacost.append(dfcheap.sum(axis=1))
        indexcost.append('Cheap')
        
        dfcost = pd.DataFrame(datacost, index=indexcost).T
        
        finaldf = dfcost
    else:
        finaldf = df

    finaldf['Teleportation'] = pd.Series(G.graph['teleportations'])
    
    try:
        if countfrogs and len(G.graph['waiting'])>0:
            finaldf['Waiting'] = pd.Series(G.graph['waiting'])
    except:
        pass

    line = vincent.StackedArea(finaldf)
    if not countfrogs:
        line.axis_titles(x='Rounds', y='# edges traversed')
    else:
        line.axis_titles(x='Rounds', y='# frogs')
    
    line.legend(title='Edge')
    line.width = 400
    line.height = 300
    line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=0.8)
   
    if len(expensiveedges)>0:
        line.colors(range_=['#ff0000','#50aa50','#6060aa', '#eeeeee'])

    
    line.marks[0].marks[0].properties.update = vincent.PropertySet()
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)

    line.marks[0].marks[0].properties.update.opacity = vincent.ValueRef(value=0.8)
    line.marks[0].marks[0].properties.hover.opacity = vincent.ValueRef(value=1)
        
    return line, finaldf

# %% [markdown]
# ## Run stuff

# %%
k=2
expensiveedges = []
for e in G.edges_iter():
    if random() > 1/float(k):
        expensiveedges.append(edgetokey(e))

# %%
G1 = G.copy()
randomwalk(G1, frogs, P_die)
(line1, df1) = plotrwtraversal2(G1,expensiveedges, time=G2.graph['endtime'])

# %%
G2 = G.copy()
randomwalk2(G2, frogs, P_die, 4, expensiveedges)
(line2, df2) = plotrwtraversal2(G2, expensiveedges)

# %%
print "Vanilla random walk. Cost: ", G1.graph['cost']
line1
# Out:
# Vanilla random walk. Cost:  598.0
# <div id="vis51249a62f9b048d0a2fa35666b8163bd"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Rounds", "type": "x"}, {"scale": "y", "title": "# edges traversed", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx": 0, "val": NaN}, {"col": "Cheap", "idx": 0, "val": NaN}, {"col": "Teleportation", "idx": 0, "val": NaN}, {"col": "Expensive", "idx": 1, "val": 6.0}, {"col": "Cheap", "idx": 1, "val": 7.0}, {"col": "Teleportation", "idx": 1, "val": NaN}, {"col": "Expensive", "idx": 2, "val": 6.0}, {"col": "Cheap", "idx": 2, "val": 7.0}, {"col": "Teleportation", "idx": 2, "val": NaN}, {"col": "Expensive", "idx": 3, "val": 6.0}, {"col": "Cheap", "idx": 3, "val": 7.0}, {"col": "Teleportation", "idx": 3, "val": NaN}, {"col": "Expensive", "idx": 4, "val": 6.0}, {"col": "Cheap", "idx": 4, "val": 7.0}, {"col": "Teleportation", "idx": 4, "val": NaN}, {"col": "Expensive", "idx": 5, "val": 6.0}, {"col": "Cheap", "idx": 5, "val": 7.0}, {"col": "Teleportation", "idx": 5, "val": NaN}, {"col": "Expensive", "idx": 6, "val": 6.0}, {"col": "Cheap", "idx": 6, "val": 7.0}, {"col": "Teleportation", "idx": 6, "val": NaN}, {"col": "Expensive", "idx": 7, "val": 6.0}, {"col": "Cheap", "idx": 7, "val": 7.0}, {"col": "Teleportation", "idx": 7, "val": NaN}, {"col": "Expensive", "idx": 8, "val": 6.0}, {"col": "Cheap", "idx": 8, "val": 7.0}, {"col": "Teleportation", "idx": 8, "val": NaN}, {"col": "Expensive", "idx": 9, "val": 6.0}, {"col": "Cheap", "idx": 9, "val": 7.0}, {"col": "Teleportation", "idx": 9, "val": NaN}, {"col": "Expensive", "idx": 10, "val": 6.0}, {"col": "Cheap", "idx": 10, "val": 7.0}, {"col": "Teleportation", "idx": 10, "val": NaN}, {"col": "Expensive", "idx": 11, "val": 6.0}, {"col": "Cheap", "idx": 11, "val": 7.0}, {"col": "Teleportation", "idx": 11, "val": NaN}, {"col": "Expensive", "idx": 12, "val": 6.0}, {"col": "Cheap", "idx": 12, "val": 7.0}, {"col": "Teleportation", "idx": 12, "val": NaN}, {"col": "Expensive", "idx": 13, "val": 6.0}, {"col": "Cheap", "idx": 13, "val": 7.0}, {"col": "Teleportation", "idx": 13, "val": NaN}, {"col": "Expensive", "idx": 14, "val": 6.0}, {"col": "Cheap", "idx": 14, "val": 7.0}, {"col": "Teleportation", "idx": 14, "val": NaN}, {"col": "Expensive", "idx": 15, "val": 6.0}, {"col": "Cheap", "idx": 15, "val": 7.0}, {"col": "Teleportation", "idx": 15, "val": NaN}, {"col": "Expensive", "idx": 16, "val": 6.0}, {"col": "Cheap", "idx": 16, "val": 7.0}, {"col": "Teleportation", "idx": 16, "val": NaN}, {"col": "Expensive", "idx": 17, "val": 6.0}, {"col": "Cheap", "idx": 17, "val": 7.0}, {"col": "Teleportation", "idx": 17, "val": NaN}, {"col": "Expensive", "idx": 18, "val": 6.0}, {"col": "Cheap", "idx": 18, "val": 7.0}, {"col": "Teleportation", "idx": 18, "val": NaN}, {"col": "Expensive", "idx": 19, "val": 6.0}, {"col": "Cheap", "idx": 19, "val": 7.0}, {"col": "Teleportation", "idx": 19, "val": NaN}, {"col": "Expensive", "idx": 20, "val": 6.0}, {"col": "Cheap", "idx": 20, "val": 7.0}, {"col": "Teleportation", "idx": 20, "val": NaN}, {"col": "Expensive", "idx": 21, "val": 6.0}, {"col": "Cheap", "idx": 21, "val": 7.0}, {"col": "Teleportation", "idx": 21, "val": NaN}, {"col": "Expensive", "idx": 22, "val": 6.0}, {"col": "Cheap", "idx": 22, "val": 7.0}, {"col": "Teleportation", "idx": 22, "val": NaN}, {"col": "Expensive", "idx": 23, "val": 6.0}, {"col": "Cheap", "idx": 23, "val": 7.0}, {"col": "Teleportation", "idx": 23, "val": NaN}, {"col": "Expensive", "idx": 24, "val": 6.0}, {"col": "Cheap", "idx": 24, "val": 7.0}, {"col": "Teleportation", "idx": 24, "val": NaN}, {"col": "Expensive", "idx": 25, "val": 6.0}, {"col": "Cheap", "idx": 25, "val": 7.0}, {"col": "Teleportation", "idx": 25, "val": NaN}, {"col": "Expensive", "idx": 26, "val": 6.0}, {"col": "Cheap", "idx": 26, "val": 7.0}, {"col": "Teleportation", "idx": 26, "val": NaN}, {"col": "Expensive", "idx": 27, "val": 6.0}, {"col": "Cheap", "idx": 27, "val": 7.0}, {"col": "Teleportation", "idx": 27, "val": NaN}, {"col": "Expensive", "idx": 28, "val": 6.0}, {"col": "Cheap", "idx": 28,  ...

# %%
print "Waiting random walk. Cost: ", G2.graph['cost']
line2
# Out:
# Waiting random walk. Cost:  319.0
# <div id="vis766faa94048b4fe6ab67355697d9007e"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Rounds", "type": "x"}, {"scale": "y", "title": "# edges traversed", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx": 1, "val": 3.0}, {"col": "Cheap", "idx": 1, "val": 7.0}, {"col": "Teleportation", "idx": 1, "val": NaN}, {"col": "Expensive", "idx": 2, "val": NaN}, {"col": "Cheap", "idx": 2, "val": 7.0}, {"col": "Teleportation", "idx": 2, "val": NaN}, {"col": "Expensive", "idx": 3, "val": 3.0}, {"col": "Cheap", "idx": 3, "val": 7.0}, {"col": "Teleportation", "idx": 3, "val": NaN}, {"col": "Expensive", "idx": 4, "val": NaN}, {"col": "Cheap", "idx": 4, "val": 7.0}, {"col": "Teleportation", "idx": 4, "val": NaN}, {"col": "Expensive", "idx": 5, "val": 3.0}, {"col": "Cheap", "idx": 5, "val": 7.0}, {"col": "Teleportation", "idx": 5, "val": NaN}, {"col": "Expensive", "idx": 6, "val": NaN}, {"col": "Cheap", "idx": 6, "val": 7.0}, {"col": "Teleportation", "idx": 6, "val": NaN}, {"col": "Expensive", "idx": 7, "val": 3.0}, {"col": "Cheap", "idx": 7, "val": 7.0}, {"col": "Teleportation", "idx": 7, "val": NaN}, {"col": "Expensive", "idx": 8, "val": NaN}, {"col": "Cheap", "idx": 8, "val": 7.0}, {"col": "Teleportation", "idx": 8, "val": NaN}, {"col": "Expensive", "idx": 9, "val": 3.0}, {"col": "Cheap", "idx": 9, "val": 7.0}, {"col": "Teleportation", "idx": 9, "val": NaN}, {"col": "Expensive", "idx": 10, "val": NaN}, {"col": "Cheap", "idx": 10, "val": 7.0}, {"col": "Teleportation", "idx": 10, "val": NaN}, {"col": "Expensive", "idx": 11, "val": 3.0}, {"col": "Cheap", "idx": 11, "val": 7.0}, {"col": "Teleportation", "idx": 11, "val": NaN}, {"col": "Expensive", "idx": 12, "val": NaN}, {"col": "Cheap", "idx": 12, "val": 7.0}, {"col": "Teleportation", "idx": 12, "val": NaN}, {"col": "Expensive", "idx": 13, "val": 3.0}, {"col": "Cheap", "idx": 13, "val": 7.0}, {"col": "Teleportation", "idx": 13, "val": NaN}, {"col": "Expensive", "idx": 14, "val": NaN}, {"col": "Cheap", "idx": 14, "val": 7.0}, {"col": "Teleportation", "idx": 14, "val": NaN}, {"col": "Expensive", "idx": 15, "val": 3.0}, {"col": "Cheap", "idx": 15, "val": 7.0}, {"col": "Teleportation", "idx": 15, "val": NaN}, {"col": "Expensive", "idx": 16, "val": NaN}, {"col": "Cheap", "idx": 16, "val": 7.0}, {"col": "Teleportation", "idx": 16, "val": NaN}, {"col": "Expensive", "idx": 17, "val": 3.0}, {"col": "Cheap", "idx": 17, "val": 7.0}, {"col": "Teleportation", "idx": 17, "val": NaN}, {"col": "Expensive", "idx": 18, "val": NaN}, {"col": "Cheap", "idx": 18, "val": 7.0}, {"col": "Teleportation", "idx": 18, "val": NaN}, {"col": "Expensive", "idx": 19, "val": 3.0}, {"col": "Cheap", "idx": 19, "val": 7.0}, {"col": "Teleportation", "idx": 19, "val": NaN}, {"col": "Expensive", "idx": 20, "val": NaN}, {"col": "Cheap", "idx": 20, "val": 7.0}, {"col": "Teleportation", "idx": 20, "val": NaN}, {"col": "Expensive", "idx": 21, "val": 3.0}, {"col": "Cheap", "idx": 21, "val": 7.0}, {"col": "Teleportation", "idx": 21, "val": NaN}, {"col": "Expensive", "idx": 22, "val": NaN}, {"col": "Cheap", "idx": 22, "val": 7.0}, {"col": "Teleportation", "idx": 22, "val": NaN}, {"col": "Expensive", "idx": 23, "val": 3.0}, {"col": "Cheap", "idx": 23, "val": 7.0}, {"col": "Teleportation", "idx": 23, "val": NaN}, {"col": "Expensive", "idx": 24, "val": NaN}, {"col": "Cheap", "idx": 24, "val": 7.0}, {"col": "Teleportation", "idx": 24, "val": NaN}, {"col": "Expensive", "idx": 25, "val": 3.0}, {"col": "Cheap", "idx": 25, "val": 7.0}, {"col": "Teleportation", "idx": 25, "val": NaN}, {"col": "Expensive", "idx": 26, "val": NaN}, {"col": "Cheap", "idx": 26, "val": 7.0}, {"col": "Teleportation", "idx": 26, "val": NaN}, {"col": "Expensive", "idx": 27, "val": 3.0}, {"col": "Cheap", "idx": 27, "val": 7.0}, {"col": "Teleportation", "idx": 27, "val": NaN}, {"col": "Expensive", "idx": 28, "val": NaN}, {"col": "Cheap", "idx": 28, "val": 7.0}, {"col": "Teleportation", "idx": 28, "val": NaN}, {"col": "Expensive", "idx": 29, "val": 3.0}, {"col": "Cheap", "idx": 2 ...

# %%
print "Average death round adjustment:", G2.graph['death_times_sum'] / float(L*frogs)
print "Cost adjustment:", G2.graph['cost'] / float(G1.graph['cost'])
# Out:
# Average death round adjustment: 1.77433333333
# Cost adjustment: 0.533444816054

# %%
(l, d) = plotrwtraversal2(G2, countfrogs=True, expensiveedges = expensiveedges)
l
# Out:
# <div id="vis7d5caeccb54e4e8ea8256cb02aec5d64"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Rounds", "type": "x"}, {"scale": "y", "title": "# frogs", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx": 1, "val": 222.0}, {"col": "Cheap", "idx": 1, "val": 514.0}, {"col": "Teleportation", "idx": 1, "val": NaN}, {"col": "Waiting", "idx": 1, "val": 211.0}, {"col": "Expensive", "idx": 2, "val": NaN}, {"col": "Cheap", "idx": 2, "val": 396.0}, {"col": "Teleportation", "idx": 2, "val": NaN}, {"col": "Waiting", "idx": 2, "val": 505.0}, {"col": "Expensive", "idx": 3, "val": 437.0}, {"col": "Cheap", "idx": 3, "val": 223.0}, {"col": "Teleportation", "idx": 3, "val": NaN}, {"col": "Waiting", "idx": 3, "val": 227.0}, {"col": "Expensive", "idx": 4, "val": NaN}, {"col": "Cheap", "idx": 4, "val": 292.0}, {"col": "Teleportation", "idx": 4, "val": NaN}, {"col": "Waiting", "idx": 4, "val": 559.0}, {"col": "Expensive", "idx": 5, "val": 414.0}, {"col": "Cheap", "idx": 5, "val": 170.0}, {"col": "Teleportation", "idx": 5, "val": NaN}, {"col": "Waiting", "idx": 5, "val": 247.0}, {"col": "Expensive", "idx": 6, "val": NaN}, {"col": "Cheap", "idx": 6, "val": 299.0}, {"col": "Teleportation", "idx": 6, "val": NaN}, {"col": "Waiting", "idx": 6, "val": 512.0}, {"col": "Expensive", "idx": 7, "val": 389.0}, {"col": "Cheap", "idx": 7, "val": 178.0}, {"col": "Teleportation", "idx": 7, "val": NaN}, {"col": "Waiting", "idx": 7, "val": 229.0}, {"col": "Expensive", "idx": 8, "val": NaN}, {"col": "Cheap", "idx": 8, "val": 269.0}, {"col": "Teleportation", "idx": 8, "val": NaN}, {"col": "Waiting", "idx": 8, "val": 501.0}, {"col": "Expensive", "idx": 9, "val": 375.0}, {"col": "Cheap", "idx": 9, "val": 161.0}, {"col": "Teleportation", "idx": 9, "val": NaN}, {"col": "Waiting", "idx": 9, "val": 218.0}, {"col": "Expensive", "idx": 10, "val": NaN}, {"col": "Cheap", "idx": 10, "val": 254.0}, {"col": "Teleportation", "idx": 10, "val": NaN}, {"col": "Waiting", "idx": 10, "val": 466.0}, {"col": "Expensive", "idx": 11, "val": 360.0}, {"col": "Cheap", "idx": 11, "val": 155.0}, {"col": "Teleportation", "idx": 11, "val": NaN}, {"col": "Waiting", "idx": 11, "val": 193.0}, {"col": "Expensive", "idx": 12, "val": NaN}, {"col": "Cheap", "idx": 12, "val": 237.0}, {"col": "Teleportation", "idx": 12, "val": NaN}, {"col": "Waiting", "idx": 12, "val": 445.0}, {"col": "Expensive", "idx": 13, "val": 337.0}, {"col": "Cheap", "idx": 13, "val": 143.0}, {"col": "Teleportation", "idx": 13, "val": NaN}, {"col": "Waiting", "idx": 13, "val": 194.0}, {"col": "Expensive", "idx": 14, "val": NaN}, {"col": "Cheap", "idx": 14, "val": 243.0}, {"col": "Teleportation", "idx": 14, "val": NaN}, {"col": "Waiting", "idx": 14, "val": 402.0}, {"col": "Expensive", "idx": 15, "val": 326.0}, {"col": "Cheap", "idx": 15, "val": 133.0}, {"col": "Teleportation", "idx": 15, "val": NaN}, {"col": "Waiting", "idx": 15, "val": 172.0}, {"col": "Expensive", "idx": 16, "val": NaN}, {"col": "Cheap", "idx": 16, "val": 205.0}, {"col": "Teleportation", "idx": 16, "val": NaN}, {"col": "Waiting", "idx": 16, "val": 405.0}, {"col": "Expensive", "idx": 17, "val": 304.0}, {"col": "Cheap", "idx": 17, "val": 130.0}, {"col": "Teleportation", "idx": 17, "val": NaN}, {"col": "Waiting", "idx": 17, "val": 169.0}, {"col": "Expensive", "idx": 18, "val": NaN}, {"col": "Cheap", "idx": 18, "val": 208.0}, {"col": "Teleportation", "idx": 18, "val": NaN}, {"col": "Waiting", "idx": 18, "val": 366.0}, {"col": "Expensive", "idx": 19, "val": 272.0}, {"col": "Cheap", "idx": 19, "val": 125.0}, {"col": "Teleportation", "idx": 19, "val": NaN}, {"col": "Waiting", "idx": 19, "val": 164.0}, {"col": "Expensive", "idx": 20, "val": NaN}, {"col": "Cheap", "idx": 20, "val": 186.0}, {"col": "Teleportation", "idx": 20, "val": NaN}, {"col": "Waiting", "idx": 20, "val": 357.0}, {"col": "Expensive", "idx": 21, "val": 268.0}, {"col": "Cheap", "idx": 21, "val": 115.0}, {"col": "Teleportation", "idx": 21, "val": NaN}, {"col": "Waiting", "idx": 21, "val": 149.0}, {"col": "Expensive", "idx ...
