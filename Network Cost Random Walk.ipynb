# %%
import networkx as nx
import numpy as np
from random import randrange, choice, random
import math

# %%
import json
from networkx.readwrite import json_graph

# %%
import pandas as pd
import vincent
vincent.initialize_notebook()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %% [markdown]
# # Generate graph

# %%
n = 50
m = 2
p = 0.3

# %%
G = nx.barbell_graph(4,0)

# %%
G = nx.scale_free_graph(n)

# %%
G = nx.powerlaw_cluster_graph(n=n, m=m, p=p)

# %%
G = nx.cycle_graph(50)

# %% [markdown]
# ### Save and Plot Graph

# %%
d = json_graph.node_link_data(G)
for node in d['nodes']:
    node['name']=node['id']
    node['value']=G.degree(node['id'])

d['adjacency'] = json_graph.adjacency_data(G)['adjacency']
json.dump(d, open('graph.json','w'))

# %%
# %%html
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>
# Out:
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>

# %% [markdown]
# ### Convert to DiGraph, if necessary

# %%
if G.is_multigraph():
    if G.is_directed():
        Gm = G.copy()
        G = nx.DiGraph()
        for (u,v) in Gm.edges_iter():
            G.add_edge(u,v)

# %% [markdown]
# # Simulate Random Walks

# %%
frogs = 1000

# %%
# Life expectancy L. L should be the mean of a geometric distribution
L = int(math.ceil(10*math.log(G.order())))

# %%
# P_die is the probability that a frog dies at any given time
P_die = 1/float(L)

# %% [markdown]
# # New development

# %%
def edgetokey(e):
    (u,v) = e
    return '(' + str(u) + ', ' + str(v) + ')'

# %%
def isexpensive(G,expensiveedges,e):
    if G.is_directed():
        return edgetokey(e) in expensiveedges
    else:
        (u,v) = e
        return edgetokey((u,v)) in expensiveedges or edgetokey((v,u)) in expensiveedges

# %%
def dictcounter(d, k, v=1):
    try:
        d[k] += v
    except:
        d[k] = v

# %%
def randomwalkold(G, frogs, P_die):
    frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs).tolist()
    G.graph['teleportations'] = {}
    for node in G.nodes_iter():
        G.node[node]['visits'] = 0
        G.node[node]['deaths'] = 0
    # Initialize edge traversal counters
    for e in G.edges_iter():
        G.edge[e[0]][e[1]]['timeline'] = {}
    frogs_left = frogs
    time = 0
    G.graph['total_visits'] = 0
    G.graph['death_times_sum'] = 0

    while frogs_left:
        time +=1
        for f in range(frogs):
            curloc = frog_locations[f]

            # Skip dead frogs
            if curloc == None:
                continue

            # Flip coin to die
            if random() < P_die:
                G.node[curloc]['deaths'] += 1
                G.graph['death_times_sum'] += time
                frog_locations[f] = None
                frogs_left -= 1
                continue

            G.graph['total_visits'] +=1

            # Node has successors
            if len(G[curloc])>0:
                frog_locations[f] = choice(G[curloc].keys())
                loc = frog_locations[f]

                dictcounter(G.edge[curloc][loc]['timeline'], time)

            # Node does not have successors - Teleport
            else:
                frog_locations[f] = np.random.randint(0, high = G.number_of_nodes())
                dictcounter(G.graph['teleportations'],time)


            G.node[frog_locations[f]]['visits'] +=1
            
        G.graph['endtime'] = time

# %%
def plotrwresult(G):
    visits = [G.node[node]['visits'] for node in G.nodes_iter() ]
    norm_visits = np.array(visits)/float(G.graph['total_visits'])

    deaths = [G.node[node]['deaths'] for node in G.nodes_iter() ]
    norm_deaths = np.array(deaths)/float(sum(deaths))

    if G.is_directed():
        degrees = [ G.in_degree(node) for node in G.nodes_iter() ]
        norm_degrees = np.array(degrees)/float(G.size())
    else:
        degrees = [ G.degree(node) for node in G.nodes_iter() ]
        norm_degrees = np.array(degrees)/float(2*G.size())

    multi_iter1 = {'index':range(G.order()), 'Visits':norm_visits, 'Deaths':norm_deaths, 'Degree':norm_degrees}
    line = vincent.Scatter(multi_iter1, iter_idx='index')
    line.axis_titles(x='Vertex', y='Juice')
    line.legend(title='Results')
    line.width = 400
    line.height = 300
    line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=1)
    
    line.marks[0].marks[0].properties.update = vincent.PropertySet()
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)
    line.scales['shape'] = vincent.Scale(name='shape', type='ordinal',
                          domain=vincent.DataRef(data='table', field='data.col'),
                          range=["square", "circle", "triangle-down", "triangle-up"])
    line.marks[0].marks[0].properties.enter.shape = vincent.ValueRef(scale="shape", field="data.col")
    line.legends[0].shape = "shape" 
    
    return line

# %%
def randomwalk(G, frogs, P_die, T=10, expensiveedges = []):
    G.graph['teleportations'] = {}
    G.graph['waiting'] = {}
    for node in G.nodes_iter():
        G.node[node]['visits'] = 0
        G.node[node]['deaths'] = 0
        G.node[node]['frogs'] = 0
        G.node[node]['incomingfrogs'] = 0
    # Initialize edge traversal counters
    for e in G.edges_iter():
        G.edge[e[0]][e[1]]['timeline'] = {}
        if not G.is_directed():
            G.edge[e[0]][e[1]]['frogstosmall'] = 0
            G.edge[e[0]][e[1]]['frogstolarge'] = 0
        else:
            G.edge[e[0]][e[1]]['frogs'] = 0
        
    frogs_left = frogs
    time = 0
    G.graph['total_visits'] = 0
    G.graph['death_times_sum'] = 0
    
    frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs).tolist()
    for i in range(frogs):
        G.node[frog_locations[i]]['frogs'] += 1
    del frog_locations
    
    while frogs_left:
        time +=1
        
        # Deal with old node frogs
        for node in G.nodes_iter():
            if G.node[node]['frogs'] == 0:
                continue
            for f in range(G.node[node]['frogs']):
                # Flip coin to die
                if random() < P_die:
                    G.node[node]['deaths'] += 1
                    G.graph['death_times_sum'] += time
                    frogs_left -= 1
                    continue
                G.graph['total_visits'] +=1
                # Node has successors
                if len(G[node])>0:
                    loc = choice(G[node].keys())
                    if G.is_directed():
                        G.edge[node][loc]['frogs'] += 1
                    else:
                        if loc >= node:
                            G.edge[node][loc]['frogstolarge'] += 1
                        else:
                            G.edge[node][loc]['frogstosmall'] += 1
                # Node does not have successors - Teleport
                else:
                    loc = np.random.randint(0, high = G.number_of_nodes())
                    dictcounter(G.graph['teleportations'],time)
                    G.node[loc]['incomingfrogs'] += 1
                G.node[loc]['visits'] +=1
            G.node[node]['frogs'] = 0
            
        # Deal with edge frogs
        for (u,v) in G.edges_iter():
            # Don't process expensive edges unless time is multiple of T
            if isexpensive(G, expensiveedges, (u,v)) and not (time % T == ((u+v) % T)):
            #if isexpensive(G, expensiveedges, (u,v)) and not (time % T == 0):
                if G.is_directed():
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogs'])
                else:
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogstosmall'])
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogstolarge'])
                continue
            
            if G.is_directed():
                G.node[v]['incomingfrogs'] += G.edge[u][v]['frogs']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogs'])
                G.edge[u][v]['frogs'] = 0
            else:
                if v >= u:
                    large = v
                    small = u
                else:
                    large = u
                    small = v
                    
                G.node[large]['incomingfrogs'] += G.edge[u][v]['frogstolarge']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogstolarge'])
                G.edge[u][v]['frogstolarge'] = 0
                
                G.node[small]['incomingfrogs'] += G.edge[u][v]['frogstosmall']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogstosmall'])
                G.edge[u][v]['frogstosmall'] = 0
                
        # Deal with node incoming frogs
        for node in G.nodes_iter():
            G.node[node]['frogs'] += G.node[node]['incomingfrogs']
            G.node[node]['incomingfrogs'] = 0

    G.graph['endtime'] = time

# %%
def plotrwtraversal(G, expensiveedges=[], time=None, countfrogs = False):
    data = []
    index = []

    for e in G.edges_iter():
        key = edgetokey((e[0], e[1]))
        sr = pd.Series(G.edge[e[0]][e[1]]['timeline'])
        if not countfrogs:
            sr[sr>0] = 1
        data.append(sr)
        index.append(key)
    
    if time:
        data.append(pd.Series(time*[0]))
        index.append('hack')
    
    df = pd.DataFrame(data, index=index).T
          
    if time:
        del df['hack']
        
    dfexp = df[expensiveedges].copy()
    dfcheap = df.copy()
    dfcheap.drop(expensiveedges, 1, inplace=True)
    
    dfexpcopy = dfexp.copy()
    dfexpcopy[dfexp>0] = 1
    cost = (dfexpcopy.sum(axis=1)).sum()
    
    G.graph['cost'] = cost
    
    if len(expensiveedges)>0:
        datacost = []
        indexcost = []
        datacost.append(dfexp.sum(axis=1))
        indexcost.append('Expensive')
        datacost.append(dfcheap.sum(axis=1))
        indexcost.append('Cheap')
        
        dfcost = pd.DataFrame(datacost, index=indexcost).T
        
        finaldf = dfcost
    else:
        finaldf = df

    showteleportations = (len(G.graph['teleportations'])>0) and countfrogs

    if showteleportations:
    # Count teleportations
        finaldf['Teleportation'] = pd.Series(G.graph['teleportations'])
    
    try:
        if countfrogs and len(G.graph['waiting'])>0:
            finaldf['Waiting'] = pd.Series(G.graph['waiting'])
    except:
        pass

    line = vincent.StackedArea(finaldf)
    if not countfrogs:
        line.axis_titles(x='Rounds', y='# edges traversed')
    else:
        line.axis_titles(x='Rounds', y='# frogs')
    
    line.legend(title='Edge')
    line.width = 400
    line.height = 300
    line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=0.8)
   
    if len(expensiveedges)>0:
        if showteleportations:
            line.colors(range_=['#ff0000','#50aa50','#6060aa', '#eeeeee'])
        else:
            line.colors(range_=['#ff0000','#50aa50', '#eeeeee'])

    
    line.marks[0].marks[0].properties.update = vincent.PropertySet()
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)

    line.marks[0].marks[0].properties.update.opacity = vincent.ValueRef(value=0.8)
    line.marks[0].marks[0].properties.hover.opacity = vincent.ValueRef(value=1)
        
    return line, finaldf

# %% [markdown]
# # Simulations

# %% [markdown]
# ### Randomize expensive edges

# %%
k=10
expensiveedges = []
for e in G.edges_iter():
    if random() > 1/float(k):
        expensiveedges.append(edgetokey(e))

# %% [markdown]
# ### Run algorithms

# %%
G1 = G.copy()
randomwalk(G1, frogs, P_die)
G2 = G.copy()
randomwalk(G2, frogs, P_die, 4, expensiveedges)

# %% [markdown]
# ### Make plots

# %%
(line1, df1) = plotrwtraversal(G1,expensiveedges, time=G2.graph['endtime']+1)
(line2, df2) = plotrwtraversal(G2, expensiveedges)

# %%
print "Vanilla random walk. Cost: ", G1.graph['cost']; line1
# Out:
# Vanilla random walk. Cost:  6480.0
# <div id="visfa324f7f02544d1084f951723a1e7bc8"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Rounds", "type": "x"}, {"scale": "y", "title": "# edges traversed", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx":
, {"col": "Cheap", "idx": 32, "val": 3.0}, {"col": "Expensive", "idx": 33, "val": 47.0}, {"col": "Cheap", "idx": 33, "val": 3.0}, {"col": "Expensive", "idx": 34, "val": 47.0}, {"col": "Cheap", "idx": 34, "val": 3.0}, {"col": "Expensive", "idx": 35, "val": 47.0}, {"col": "Cheap", "idx": 35, "val": 3.0}, {"col": "Expensive", "idx": 36, "val": 47.0}, {"col": "Cheap", "idx": 36, "val": 3.0}, {"col": "Expensive", "idx": 37, "val": 47.0}, {"col": "Cheap", "idx": 37, "val": 3.0}, {"col": "Expensive", "idx": 38, "val": 47.0}, {"col": "Cheap", "idx": 38, "val": 3.0}, {"col": "Expensive", "idx": 39, "val": 47.0}, {"col": "Cheap", "idx": 39, "val": 3.0}, {"col": "Expensive", "idx": 40, "val": 47.0}, {"col": "Cheap", "idx": 40, "val": 3.0}, {"col": "Expensive", "idx": 41, "val": 47.0}, {"col": "Cheap", "idx": 41, "val": 3.0}, {"col": "Expensive", "idx": 42, "val": 47.0}, {"col": "Cheap", "idx": 42, "val": 3.0}, {"col": "Expensive", "idx": 43, "val": 47.0}, {"col": "Cheap", "idx": 43, "val": 3.0}, {"col": "Expensi ...

# %%
print "Vanilla random walk. Cost: ", G1.graph['cost']; line1
# Out:
# Vanilla random walk. Cost:  6480.0
# <div id="vis63c9fc51ae2b4ad4824d208f5252f71c"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Rounds", "type": "x"}, {"scale": "y", "title": "# edges traversed", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx": 0, "val": NaN}, {"col": "Cheap", "idx": 0, "val": NaN}, {"col": "Expensive", "idx": 1, "val": 47.0}, {"col": "Cheap", "idx": 1, "val": 3.0}, {"col": "Expensive", "idx": 2, "val": 47.0}, {"col": "Cheap", "idx": 2, "val": 3.0}, {"col": "Expensive", "idx": 3, "val": 47.0}, {"col": "Cheap", "idx": 3, "val": 3.0}, {"col": "Expensive", "idx": 4, "val": 47.0}, {"col": "Cheap", "idx": 4, "val": 3.0}, {"col": "Expensive", "idx": 5, "val": 47.0}, {"col": "Cheap", "idx": 5, "val": 3.0}, {"col": "Expensive", "idx": 6, "val": 47.0}, {"col": "Cheap", "idx": 6, "val": 3.0}, {"col": "Expensive", "idx": 7, "val": 47.0}, {"col": "Cheap", "idx": 7, "val": 3.0}, {"col": "Expensive", "idx": 8, "val": 47.0}, {"col": "Cheap", "idx": 8, "val": 3.0}, {"col": "Expensive", "idx": 9, "val": 47.0}, {"col": "Cheap", "idx": 9, "val": 3.0}, {"col": "Expensive", "idx": 10, "val": 47.0}, {"col": "Cheap", "idx": 10, "val": 3.0}, {"col": "Expensive", "idx": 11, "val": 47.0}, {"col": "Cheap", "idx": 11, "val": 3.0}, {"col": "Expensive", "idx": 12, "val": 47.0}, {"col": "Cheap", "idx": 12, "val": 3.0}, {"col": "Expensive", "idx": 13, "val": 47.0}, {"col": "Cheap", "idx": 13, "val": 3.0}, {"col": "Expensive", "idx": 14, "val": 47.0}, {"col": "Cheap", "idx": 14, "val": 3.0}, {"col": "Expensive", "idx": 15, "val": 47.0}, {"col": "Cheap", "idx": 15, "val": 3.0}, {"col": "Expensive", "idx": 16, "val": 47.0}, {"col": "Cheap", "idx": 16, "val": 3.0}, {"col": "Expensive", "idx": 17, "val": 47.0}, {"col": "Cheap", "idx": 17, "val": 3.0}, {"col": "Expensive", "idx": 18, "val": 47.0}, {"col": "Cheap", "idx": 18, "val": 3.0}, {"col": "Expensive", "idx": 19, "val": 47.0}, {"col": "Cheap", "idx": 19, "val": 3.0}, {"col": "Expensive", "idx": 20, "val": 47.0}, {"col": "Cheap", "idx": 20, "val": 3.0}, {"col": "Expensive", "idx": 21, "val": 47.0}, {"col": "Cheap", "idx": 21, "val": 3.0}, {"col": "Expensive", "idx": 22, "val": 47.0}, {"col": "Cheap", "idx": 22, "val": 3.0}, {"col": "Expensive", "idx": 23, "val": 47.0}, {"col": "Cheap", "idx": 23, "val": 3.0}, {"col": "Expensive", "idx": 24, "val": 47.0}, {"col": "Cheap", "idx": 24, "val": 3.0}, {"col": "Expensive", "idx": 25, "val": 47.0}, {"col": "Cheap", "idx": 25, "val": 3.0}, {"col": "Expensive", "idx": 26, "val": 47.0}, {"col": "Cheap", "idx": 26, "val": 3.0}, {"col": "Expensive", "idx": 27, "val": 47.0}, {"col": "Cheap", "idx": 27, "val": 3.0}, {"col": "Expensive", "idx": 28, "val": 47.0}, {"col": "Cheap", "idx": 28, "val": 3.0}, {"col": "Expensive", "idx": 29, "val": 47.0}, {"col": "Cheap", "idx": 29, "val": 3.0}, {"col": "Expensive", "idx": 30, "val": 47.0}, {"col": "Cheap", "idx": 30, "val": 3.0}, {"col": "Expensive", "idx": 31, "val": 47.0}, {"col": "Cheap", "idx": 31, "val": 3.0}, {"col": "Expensive", "idx": 32, "val": 47.0}, {"col": "Cheap", "idx": 32, "val": 3.0}, {"col": "Expensive", "idx": 33, "val": 47.0}, {"col": "Cheap", "idx": 33, "val": 3.0}, {"col": "Expensive", "idx": 34, "val": 47.0}, {"col": "Cheap", "idx": 34, "val": 3.0}, {"col": "Expensive", "idx": 35, "val": 47.0}, {"col": "Cheap", "idx": 35, "val": 3.0}, {"col": "Expensive", "idx": 36, "val": 47.0}, {"col": "Cheap", "idx": 36, "val": 3.0}, {"col": "Expensive", "idx": 37, "val": 47.0}, {"col": "Cheap", "idx": 37, "val": 3.0}, {"col": "Expensive", "idx": 38, "val": 47.0}, {"col": "Cheap", "idx": 38, "val": 3.0}, {"col": "Expensive", "idx": 39, "val": 47.0}, {"col": "Cheap", "idx": 39, "val": 3.0}, {"col": "Expensive", "idx": 40, "val": 47.0}, {"col": "Cheap", "idx": 40, "val": 3.0}, {"col": "Expensive", "idx": 41, "val": 47.0}, {"col": "Cheap", "idx": 41, "val": 3.0}, {"col": "Expensive", "idx": 42, "val": 47.0}, {"col": "Cheap", "idx": 42, "val": 3.0}, {"col": "Expensive", "idx": 43, "val": 47.0}, {"col": "Cheap", "idx": 43, "val": 3.0}, {"col": "Expensi ...

# %%
print "Waiting random walk. Cost: ", G2.graph['cost']; line2
# Out:
# Waiting random walk. Cost:  5745.0
# <div id="vis62b821476c954c5aa27cec5ee02f78d0"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Rounds", "type": "x"}, {"scale": "y", "title": "# edges traversed", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx":
x": 34, "val": 3.0}, {"col": "Expensive", "idx": 35, "val": 23.0}, {"col": "Cheap", "idx": 35, "val": 2.0}, {"col": "Expensive", "idx": 36, "val": NaN}, {"col": "Cheap", "idx": 36, "val": 3.0}, {"col": "Expensive", "idx": 37, "val": 24.0}, {"col": "Cheap", "idx": 37, "val": 2.0}, {"col": "Expensive", "idx": 38, "val": NaN}, {"col": "Cheap", "idx": 38, "val": 3.0}, {"col": "Expensive", "idx": 39, "val": 23.0}, {"col": "Cheap", "idx": 39, "val": 2.0}, {"col": "Expensive", "idx": 40, "val": NaN}, {"col": "Cheap", "idx": 40, "val": 3.0}, {"col": "Expensive", "idx": 41, "val": 24.0}, {"col": "Cheap", "idx": 41, "val": 3.0}, {"col": "Expensive", "idx": 42, "val": NaN}, {"col": "Cheap", "idx": 42, "val": 2.0}, {"col": "Expensive", "idx": 43, "val": 23.0}, {"col": "Cheap", "idx": 43, "val": 1.0}, {"col": "Expensive", "idx": 44, "val": NaN}, {"col": "Cheap", "idx": 44, "val": 3.0}, {"col": "Expensive", "idx": 45, "va ...

# %%
print "Stats normalized by equivalent vanilla random walk stats:"
print
print "Average death round (waiting/vanilla):", G2.graph['death_times_sum'] / float(L*frogs)
print "Total duration in rounds (waiting/vanilla):", G2.graph['endtime'] / float(G1.graph['endtime'])
print "Cost (waiting/vanilla):", G2.graph['cost'] / float(G1.graph['cost'])
# Out:
# Stats normalized by equivalent vanilla random walk stats:
#
# Average death round (waiting/vanilla): 2.884125
# Total duration in rounds (waiting/vanilla): 3.42348754448
# Cost (waiting/vanilla): 0.886574074074

# %%
(l, d) = plotrwtraversal(G2, countfrogs=True, expensiveedges = expensiveedges)
print "Waiting algorithm: What are the frogs up to?"; l
# Out:
# Waiting algorithm: What are the frogs up to?
# <div id="viseb995edd898a4abc9f0a6f0b37c227ae"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Rounds", "type": "x"}, {"scale": "y", "title": "# frogs", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx": 1, "val": 443.0}, {"col": "Cheap", "idx": 1, "val": 68.0}, {"col": "Waiting", "idx": 1, "val": 463.0}, {"col": "Expensive", "idx": 2, "val": NaN}, {"col": "Cheap", "idx": 2, "val": 39.0}, {"col": "Waiting", "idx": 2, "val": 925.0}, {"col": "Expensive", "idx": 3, "val": 689.0}, {"col": "Cheap", "idx": 3, "val": 23.0}, {"col": "Waiting", "idx": 3, "val": 251.0}, {"col": "Expensive", "idx": 4, "val": NaN}, {"col": "Cheap", "idx": 4, "val": 26.0}, {"col": "Waiting", "idx": 4, "val": 918.0}, {"col": "Expensive", "idx": 5, "val": 555.0}, {"col": "Cheap", "idx": 5, "val": 13.0}, {"col": "Waiting", "idx": 5, "val": 376.0}, {"col": "Expensive", "idx": 6, "val": NaN}, {"col": "Cheap", "idx": 6, "val": 19.0}, {"col": "Waiting", "idx": 6, "val": 905.0}, {"col": "Expensive", "idx": 7, "val": 621.0}, {"col": "Cheap", "idx": 7, "val": 7.0}, {"col": "Waiting", "idx": 7, "val": 296.0}, {"col": "Expensive", "idx": 8, "val": NaN}, {"col": "Cheap", "idx": 8, "val": 35.0}, {"col": "Waiting", "idx": 8, "val": 874.0}, {"col": "Expensive", "idx": 9, "val": 580.0}, {"col": "Cheap", "idx": 9, "val": 17.0}, {"col": "Waiting", "idx": 9, "val": 311.0}, {"col": "Expensive", "idx": 10, "val": NaN}, {"col": "Cheap", "idx": 10, "val": 26.0}, {"col": "Waiting", "idx": 10, "val": 870.0}, {"col": "Expensive", "idx": 11, "val": 571.0}, {"col": "Cheap", "idx": 11, "val": 16.0}, {"col": "Waiting", "idx": 11, "val": 309.0}, {"col": "Expensive", "idx": 12, "val": NaN}, {"col": "Cheap", "idx": 12, "val": 40.0}, {"col": "Waiting", "idx": 12, "val": 849.0}, {"col": "Expensive", "idx": 13, "val": 576.0}, {"col": "Cheap", "idx": 13, "val": 20.0}, {"col": "Waiting", "idx": 13, "val": 293.0}, {"col": "Expensive", "idx": 14, "val": NaN}, {"col": "Cheap", "idx": 14, "val": 24.0}, {"col": "Waiting", "idx": 14, "val": 846.0}, {"col": "Expensive", "idx": 15, "val": 531.0}, {"col": "Cheap", "idx": 15, "val": 14.0}, {"col": "Waiting", "idx": 15, "val": 323.0}, {"col": "Expensive", "idx": 16, "val": NaN}, {"col": "Cheap", "idx": 16, "val": 31.0}, {"col": "Waiting", "idx": 16, "val": 827.0}, {"col": "Expensive", "idx": 17, "val": 572.0}, {"col": "Cheap", "idx": 17, "val": 14.0}, {"col": "Waiting", "idx": 17, "val": 270.0}, {"col": "Expensive", "idx": 18, "val": NaN}, {"col": "Cheap", "idx": 18, "val": 17.0}, {"col": "Waiting", "idx": 18, "val": 825.0}, {"col": "Expensive", "idx": 19, "val": 560.0}, {"col": "Cheap", "idx": 19, "val": 6.0}, {"col": "Waiting", "idx": 19, "val": 276.0}, {"col": "Expensive", "idx": 20, "val": NaN}, {"col": "Cheap", "idx": 20, "val": 26.0}, {"col": "Waiting", "idx": 20, "val": 801.0}, {"col": "Expensive", "idx": 21, "val": 505.0}, {"col": "Cheap", "idx": 21, "val": 12.0}, {"col": "Waiting", "idx": 21, "val": 309.0}, {"col": "Expensive", "idx": 22, "val": NaN}, {"col": "Cheap", "idx": 22, "val": 19.0}, {"col": "Waiting", "idx": 22, "val": 795.0}, {"col": "Expensive", "idx": 23, "val": 524.0}, {"col": "Cheap", "idx": 23, "val": 10.0}, {"col": "Waiting", "idx": 23, "val": 280.0}, {"col": "Expensive", "idx": 24, "val": NaN}, {"col": "Cheap", "idx": 24, "val": 22.0}, {"col": "Waiting", "idx": 24, "val": 775.0}, {"col": "Expensive", "idx": 25, "val": 487.0}, {"col": "Cheap", "idx": 25, "val": 13.0}, {"col": "Waiting", "idx": 25, "val": 296.0}, {"col": "Expensive", "idx": 26, "val": NaN}, {"col": "Cheap", "idx": 26, "val": 22.0}, {"col": "Waiting", "idx": 26, "val": 759.0}, {"col": "Expensive", "idx": 27, "val": 504.0}, {"col": "Cheap", "idx": 27, "val": 16.0}, {"col": "Waiting", "idx": 27, "val": 261.0}, {"col": "Expensive", "idx": 28, "val": NaN}, {"col": "Cheap", "idx": 28, "val": 25.0}, {"col": "Waiting", "idx": 28, "val": 747.0}, {"col": "Expensive", "idx": 29, "val": 473.0}, {"col": "Cheap", "idx": 29, "val": 7.0}, {"col": "Waiting", "idx": 29, "val": 290.0}, {"col ...
