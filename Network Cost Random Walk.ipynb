# %%
import networkx as nx
import numpy as np
from random import randrange, choice, random
import math

# %%
import json
from networkx.readwrite import json_graph

# %%
import pandas as pd
import vincent
vincent.initialize_notebook()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %% [markdown]
# # Generate graph

# %%
n = 8
m = 2
p = 0.3

# %%
G = nx.barbell_graph(4,0)

# %%
G = nx.scale_free_graph(n)

# %%
G = nx.powerlaw_cluster_graph(n=n, m=m, p=p)

# %%
G = nx.cycle_graph(10)

# %% [markdown]
# ### Save and Plot Graph

# %%
d = json_graph.node_link_data(G)
for node in d['nodes']:
    node['name']=node['id']
    node['value']=G.degree(node['id'])

d['adjacency'] = json_graph.adjacency_data(G)['adjacency']
json.dump(d, open('graph.json','w'))

# %%
# %%html
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>
# Out:
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>

# %% [markdown]
# ### Convert to DiGraph, if necessary

# %%
if G.is_multigraph():
    if G.is_directed():
        Gm = G.copy()
        G = nx.DiGraph()
        for (u,v) in Gm.edges_iter():
            G.add_edge(u,v)

# %% [markdown]
# # Simulate Random Walks

# %%
frogs = 1000

# %%
# Life expectancy L. L should be the mean of a geometric distribution
L = int(math.ceil(10*math.log(G.order())))

# %%
# P_die is the probability that a frog dies at any given time
P_die = 1/float(L)

# %% [markdown]
# # New development

# %%
def edgetokey(e):
    (u,v) = e
    return '(' + str(u) + ', ' + str(v) + ')'

# %%
def isexpensive(G,expensiveedges,e):
    if G.is_directed():
        return edgetokey(e) in expensiveedges
    else:
        (u,v) = e
        return edgetokey((u,v)) in expensiveedges or edgetokey((v,u)) in expensiveedges

# %%
def dictcounter(d, k, v=1):
    try:
        d[k] += v
    except:
        d[k] = v

# %%
def randomwalk(G, frogs, P_die):
    frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs).tolist()
    G.graph['teleportations'] = {}
    for node in G.nodes_iter():
        G.node[node]['visits'] = 0
        G.node[node]['deaths'] = 0
    # Initialize edge traversal counters
    for e in G.edges_iter():
        G.edge[e[0]][e[1]]['timeline'] = {}
    frogs_left = frogs
    time = 0
    G.graph['total_visits'] = 0
    G.graph['death_times_sum'] = 0

    while frogs_left:
        time +=1
        for f in range(frogs):
            curloc = frog_locations[f]

            # Skip dead frogs
            if curloc == None:
                continue

            # Flip coin to die
            if random() < P_die:
                G.node[curloc]['deaths'] += 1
                G.graph['death_times_sum'] += time
                frog_locations[f] = None
                frogs_left -= 1
                continue

            G.graph['total_visits'] +=1

            # Node has successors
            if len(G[curloc])>0:
                frog_locations[f] = choice(G[curloc].keys())
                loc = frog_locations[f]

                dictcounter(G.edge[curloc][loc]['timeline'], time)

            # Node does not have successors - Teleport
            else:
                frog_locations[f] = np.random.randint(0, high = G.number_of_nodes())
                dictcounter(G.graph['teleportations'],time)


            G.node[frog_locations[f]]['visits'] +=1

# %%
def plotrwresult(G):
    visits = [G.node[node]['visits'] for node in G.nodes_iter() ]
    norm_visits = np.array(visits)/float(G.graph['total_visits'])

    deaths = [G.node[node]['deaths'] for node in G.nodes_iter() ]
    norm_deaths = np.array(deaths)/float(sum(deaths))

    if G.is_directed():
        degrees = [ G.in_degree(node) for node in G.nodes_iter() ]
        norm_degrees = np.array(degrees)/float(G.size())
    else:
        degrees = [ G.degree(node) for node in G.nodes_iter() ]
        norm_degrees = np.array(degrees)/float(2*G.size())

    multi_iter1 = {'index':range(G.order()), 'Visits':norm_visits, 'Deaths':norm_deaths, 'Degree':norm_degrees}
    line = vincent.Scatter(multi_iter1, iter_idx='index')
    line.axis_titles(x='Vertex', y='Juice')
    line.legend(title='Results')
    line.width = 400
    line.height = 300
    line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=1)
    
    line.marks[0].marks[0].properties.update = vincent.PropertySet()
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)
    line.scales['shape'] = vincent.Scale(name='shape', type='ordinal',
                          domain=vincent.DataRef(data='table', field='data.col'),
                          range=["square", "circle", "triangle-down", "triangle-up"])
    line.marks[0].marks[0].properties.enter.shape = vincent.ValueRef(scale="shape", field="data.col")
    line.legends[0].shape = "shape" 
    
    return line

# %%
def plotrwtraversal(G, expensiveedges=[]):
    data = []
    index = []

    for e in G.edges_iter():
        key = edgetokey((e[0], e[1]))
        data.append(pd.Series(G.edge[e[0]][e[1]]['timeline']))
        index.append(key)
    
    df = pd.DataFrame(data, index=index).T
          
    dfexp = df[expensiveedges].copy()
    dfcheap = df.copy()
    dfcheap.drop(expensiveedges, 1, inplace=True)
    
    dfexpcopy = dfexp.copy()
    dfexpcopy[dfexp>0] = 1
    cost = (dfexpcopy.sum(axis=1)).sum()
    
    if len(expensiveedges)>0:
        datacost = []
        indexcost = []
        datacost.append(dfexp.sum(axis=1))
        indexcost.append('Expensive')
        datacost.append(dfcheap.sum(axis=1))
        indexcost.append('Cheap')
        
        dfcost = pd.DataFrame(datacost, index=indexcost).T
        
        finaldf = dfcost
    else:
        finaldf = df

    #if len(G.graph['teleportations'])>0:
    finaldf['Teleportation'] = pd.Series(G.graph['teleportations'])
    
    try:
        if len(G.graph['waiting'])>0:
            finaldf['Waiting'] = pd.Series(G.graph['waiting'])
    except:
        pass
    
    line = vincent.StackedArea(finaldf)
    line.axis_titles(x='Time', y='# frogs')
    line.legend(title='Edge')
    line.width = 400
    line.height = 300
    line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=0.8)
   
    if len(expensiveedges)>0:
        print 'Total cost: ' + str(cost) + ' Billion dollars'
        line.colors(range_=['#ff0000','#50aa50','#6060aa', '#eeeeee'])

    
    line.marks[0].marks[0].properties.update = vincent.PropertySet()
    line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
    line.marks[0].marks[0].properties.hover = vincent.PropertySet()
    line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)

    line.marks[0].marks[0].properties.update.opacity = vincent.ValueRef(value=0.8)
    line.marks[0].marks[0].properties.hover.opacity = vincent.ValueRef(value=1)
        
    return line

# %%
def randomwalk2(G, frogs, P_die, T=10, expensiveedges = []):
    G.graph['teleportations'] = {}
    G.graph['waiting'] = {}
    for node in G.nodes_iter():
        G.node[node]['visits'] = 0
        G.node[node]['deaths'] = 0
        G.node[node]['frogs'] = 0
        G.node[node]['incomingfrogs'] = 0
    # Initialize edge traversal counters
    for e in G.edges_iter():
        G.edge[e[0]][e[1]]['timeline'] = {}
        if not G.is_directed():
            G.edge[e[0]][e[1]]['frogstosmall'] = 0
            G.edge[e[0]][e[1]]['frogstolarge'] = 0
        else:
            G.edge[e[0]][e[1]]['frogs'] = 0
        
    frogs_left = frogs
    time = 0
    G.graph['total_visits'] = 0
    G.graph['death_times_sum'] = 0
    
    frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs).tolist()
    for i in range(frogs):
        G.node[frog_locations[i]]['frogs'] += 1
    del frog_locations
    
    while frogs_left:
        time +=1
        
        # Deal with old node frogs
        for node in G.nodes_iter():
            if G.node[node]['frogs'] == 0:
                continue
            for f in range(G.node[node]['frogs']):
                # Flip coin to die
                if random() < P_die:
                    G.node[node]['deaths'] += 1
                    G.graph['death_times_sum'] += time
                    frogs_left -= 1
                    continue
                G.graph['total_visits'] +=1
                # Node has successors
                if len(G[node])>0:
                    loc = choice(G[node].keys())
                    if G.is_directed():
                        G.edge[node][loc]['frogs'] += 1
                    else:
                        if loc >= node:
                            G.edge[node][loc]['frogstolarge'] += 1
                        else:
                            G.edge[node][loc]['frogstosmall'] += 1
                # Node does not have successors - Teleport
                else:
                    loc = np.random.randint(0, high = G.number_of_nodes())
                    dictcounter(G.graph['teleportations'],time)
                    G.node[loc]['incomingfrogs'] += 1
                G.node[loc]['visits'] +=1
            G.node[node]['frogs'] = 0
            
        # Deal with edge frogs
        for (u,v) in G.edges_iter():
            # Don't process expensive edges unless time is multiple of T
            #if isexpensive(G, expensiveedges, (u,v)) and not (time % T == ((u+v) % T)):
            if isexpensive(G, expensiveedges, (u,v)) and not (time % T == 0):
                if G.is_directed():
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogs'])
                else:
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogstosmall'])
                    dictcounter(G.graph['waiting'], time, G.edge[u][v]['frogstolarge'])
                continue
            
            if G.is_directed():
                G.node[v]['incomingfrogs'] += G.edge[u][v]['frogs']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogs'])
                G.edge[u][v]['frogs'] = 0
            else:
                if v >= u:
                    large = v
                    small = u
                else:
                    large = u
                    small = v
                    
                G.node[large]['incomingfrogs'] += G.edge[u][v]['frogstolarge']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogstolarge'])
                G.edge[u][v]['frogstolarge'] = 0
                
                G.node[small]['incomingfrogs'] += G.edge[u][v]['frogstosmall']
                dictcounter(G.edge[u][v]['timeline'], time, G.edge[u][v]['frogstosmall'])
                G.edge[u][v]['frogstosmall'] = 0
                
        # Deal with node incoming frogs
        for node in G.nodes_iter():
            G.node[node]['frogs'] += G.node[node]['incomingfrogs']
            G.node[node]['incomingfrogs'] = 0

# %% [markdown]
# ## Run stuff

# %%
k=4
expensiveedges = []
for e in G.edges_iter():
    if random() > 1/float(k):
        expensiveedges.append(edgetokey(e))

# %%
G2 = G.copy()
randomwalk2(G2, frogs, P_die, 10, expensiveedges)
print "Death time inflation:", G2.graph['death_times_sum'] / float(L*frogs)
#plotrwresult(G2)
plotrwtraversal(G2, expensiveedges)
# Out:
# Death time inflation: 6.64152380952
# Total cost: 594.0 Billion dollars
# <div id="visd1c73b0126b348bc8b115646abece60d"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Time", "type": "x"}, {"scale": "y", "title": "# frogs", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx": 1, "val": NaN}, {"col": "Cheap", "idx": 1, "val": 355.0}, {"col": "Teleportation", "idx": 1, "val": NaN}, {"col": "Waiting", "idx": 1, "val": 602.0}, {"col": "Expensive", "idx": 2, "val": NaN}, {"col": "Cheap", "idx": 2, "val": 184.0}, {"col": "Teleportation", "idx": 2, "val": NaN}, {"col": "Waiting", "idx": 2, "val": 756.0}, {"col": "Expensive", "idx": 3, "val": NaN}, {"col": "Cheap", "idx": 3, "val": 95.0}, {"col": "Teleportation", "idx": 3, "val": NaN}, {"col": "Waiting", "idx": 3, "val": 835.0}, {"col": "Expensive", "idx": 4, "val": NaN}, {"col": "Cheap", "idx": 4, "val": 56.0}, {"col": "Teleportation", "idx": 4, "val": NaN}, {"col": "Waiting", "idx": 4, "val": 871.0}, {"col": "Expensive", "idx": 5, "val": NaN}, {"col": "Cheap", "idx": 5, "val": 27.0}, {"col": "Teleportation", "idx": 5, "val": NaN}, {"col": "Waiting", "idx": 5, "val": 896.0}, {"col": "Expensive", "idx": 6, "val": NaN}, {"col": "Cheap", "idx": 6, "val": 16.0}, {"col": "Teleportation", "idx": 6, "val": NaN}, {"col": "Waiting", "idx": 6, "val": 906.0}, {"col": "Expensive", "idx": 7, "val": NaN}, {"col": "Cheap", "idx": 7, "val": 6.0}, {"col": "Teleportation", "idx": 7, "val": NaN}, {"col": "Waiting", "idx": 7, "val": 916.0}, {"col": "Expensive", "idx": 8, "val": NaN}, {"col": "Cheap", "idx": 8, "val": 5.0}, {"col": "Teleportation", "idx": 8, "val": NaN}, {"col": "Waiting", "idx": 8, "val": 917.0}, {"col": "Expensive", "idx": 9, "val": NaN}, {"col": "Cheap", "idx": 9, "val": 3.0}, {"col": "Teleportation", "idx": 9, "val": NaN}, {"col": "Waiting", "idx": 9, "val": 919.0}, {"col": "Expensive", "idx": 10, "val": 920.0}, {"col": "Cheap", "idx": 10, "val": 1.0}, {"col": "Teleportation", "idx": 10, "val": NaN}, {"col": "Waiting", "idx": 10, "val": NaN}, {"col": "Expensive", "idx": 11, "val": NaN}, {"col": "Cheap", "idx": 11, "val": 228.0}, {"col": "Teleportation", "idx": 11, "val": NaN}, {"col": "Waiting", "idx": 11, "val": 662.0}, {"col": "Expensive", "idx": 12, "val": NaN}, {"col": "Cheap", "idx": 12, "val": 130.0}, {"col": "Teleportation", "idx": 12, "val": NaN}, {"col": "Waiting", "idx": 12, "val": 747.0}, {"col": "Expensive", "idx": 13, "val": NaN}, {"col": "Cheap", "idx": 13, "val": 53.0}, {"col": "Teleportation", "idx": 13, "val": NaN}, {"col": "Waiting", "idx": 13, "val": 817.0}, {"col": "Expensive", "idx": 14, "val": NaN}, {"col": "Cheap", "idx": 14, "val": 29.0}, {"col": "Teleportation", "idx": 14, "val": NaN}, {"col": "Waiting", "idx": 14, "val": 840.0}, {"col": "Expensive", "idx": 15, "val": NaN}, {"col": "Cheap", "idx": 15, "val": 8.0}, {"col": "Teleportation", "idx": 15, "val": NaN}, {"col": "Waiting", "idx": 15, "val": 860.0}, {"col": "Expensive", "idx": 16, "val": NaN}, {"col": "Cheap", "idx": 16, "val": 6.0}, {"col": "Teleportation", "idx": 16, "val": NaN}, {"col": "Waiting", "idx": 16, "val": 862.0}, {"col": "Expensive", "idx": 17, "val": NaN}, {"col": "Cheap", "idx": 17, "val": 2.0}, {"col": "Teleportation", "idx": 17, "val": NaN}, {"col": "Waiting", "idx": 17, "val": 865.0}, {"col": "Expensive", "idx": 18, "val": NaN}, {"col": "Cheap", "idx": 18, "val": 2.0}, {"col": "Teleportation", "idx": 18, "val": NaN}, {"col": "Waiting", "idx": 18, "val": 865.0}, {"col": "Expensive", "idx": 19, "val": NaN}, {"col": "Cheap", "idx": 19, "val": 2.0}, {"col": "Teleportation", "idx": 19, "val": NaN}, {"col": "Waiting", "idx": 19, "val": 865.0}, {"col": "Expensive", "idx": 20, "val": 865.0}, {"col": "Cheap", "idx": 20, "val": 2.0}, {"col": "Teleportation", "idx": 20, "val": NaN}, {"col": "Waiting", "idx": 20, "val": NaN}, {"col": "Expensive", "idx": 21, "val": NaN}, {"col": "Cheap", "idx": 21, "val": 238.0}, {"col": "Teleportation", "idx": 21, "val": NaN}, {"col": "Waiting", "idx": 21, "val": 592.0}, {"col": "Expensive", "idx": 22, "val": NaN}, {"col": "Cheap", "idx": 22, "v ...

# %%
G1 = G.copy()
randomwalk(G1, frogs, P_die)
plotrwresult(G1)
# Out:
# <div id="vis2161dca4214441d7864e2745cee5a8c3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Vertex", "type": "x"}, {"scale": "y", "title": "Juice", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Deaths", "idx": 0, "val": 0.115}, {"col": "Deaths", "idx": 1, "val": 0.13200000000000001}, {"col": "Deaths", "idx": 2, "val": 0.104}, {"col": "Deaths", "idx": 3, "val": 0.14699999999999999}, {"col": "Deaths", "idx": 4, "val": 0.14299999999999999}, {"col": "Deaths", "idx": 5, "val": 0.115}, {"col": "Deaths", "idx": 6, "val": 0.121}, {"col": "Deaths", "idx": 7, "val": 0.123}, {"col": "Degree", "idx": 0, "val": 0.11538461538461539}, {"col": "Degree", "idx": 1, "val": 0.11538461538461539}, {"col": "Degree", "idx": 2, "val": 0.11538461538461539}, {"col": "Degree", "idx": 3, "val": 0.15384615384615385}, {"col": "Degree", "idx": 4, "val": 0.15384615384615385}, {"col": "Degree", "idx": 5, "val": 0.11538461538461539}, {"col": "Degree", "idx": 6, "val": 0.11538461538461539}, {"col": "Degree", "idx": 7, "val": 0.11538461538461539}, {"col": "Visits", "idx": 0, "val": 0.10968582452272385}, {"col": "Visits", "idx": 1, "val": 0.10978603998596984}, {"col": "Visits", "idx": 2, "val": 0.11103873327654457}, {"col": "Visits", "idx": 3, "val": 0.15067394899032921}, {"col": "Visits", "idx": 4, "val": 0.15834043192864658}, {"col": "Visits", "idx": 5, "val": 0.12000801723705967}, {"col": "Visits", "idx": 6, "val": 0.12126071052763442}, {"col": "Visits", "idx": 7, "val": 0.11920629353109184}]}], "height": 300, "legends": [{"fill": "color", "offset": 0, "properties": {}, "shape": "shape", "title": "Results"}], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "opacity": {"value": 1}, "shape": {"field": "data.col", "scale": "shape"}, "size": {"value": 100}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "data.val", "scale": "y"}}, "hover": {"size": {"value": 200}}, "update": {"size": {"value": 100}}}, "type": "symbol"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "linear"}, {"domain": {"data": "table", "field": "data.val"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "ordinal"}, {"domain": {"data": "table", "field": "data.col"}, "name": "shape", "range": ["square", "circle", "triangle-down", "triangle-up"], "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis2161dca4214441d7864e2745cee5a8c3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
plotrwtraversal(G1,expensiveedges)
# Out:
# Total cost: 849.0 Billion dollars
# <div id="visdaaf7deedbb34fd0bdb11f325cb3220a"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Time", "type": "x"}, {"scale": "y", "title": "# frogs", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Expensive", "idx": 1, "val": 601.0}, {"col": "Cheap", "idx": 1, "val": 350.0}, {"col": "Teleportation", "idx": 1, "val": NaN}, {"col": "Expensive", "idx": 2, "val": 563.0}, {"col": "Cheap", "idx": 2, "val": 341.0}, {"col": "Teleportation", "idx": 2, "val": NaN}, {"col": "Expensive", "idx": 3, "val": 517.0}, {"col": "Cheap", "idx": 3, "val": 352.0}, {"col": "Teleportation", "idx": 3, "val": NaN}, {"col": "Expensive", "idx": 4, "val": 495.0}, {"col": "Cheap", "idx": 4, "val": 328.0}, {"col": "Teleportation", "idx": 4, "val": NaN}, {"col": "Expensive", "idx": 5, "val": 464.0}, {"col": "Cheap", "idx": 5, "val": 310.0}, {"col": "Teleportation", "idx": 5, "val": NaN}, {"col": "Expensive", "idx": 6, "val": 451.0}, {"col": "Cheap", "idx": 6, "val": 285.0}, {"col": "Teleportation", "idx": 6, "val": NaN}, {"col": "Expensive", "idx": 7, "val": 433.0}, {"col": "Cheap", "idx": 7, "val": 272.0}, {"col": "Teleportation", "idx": 7, "val": NaN}, {"col": "Expensive", "idx": 8, "val": 428.0}, {"col": "Cheap", "idx": 8, "val": 253.0}, {"col": "Teleportation", "idx": 8, "val": NaN}, {"col": "Expensive", "idx": 9, "val": 386.0}, {"col": "Cheap", "idx": 9, "val": 261.0}, {"col": "Teleportation", "idx": 9, "val": NaN}, {"col": "Expensive", "idx": 10, "val": 377.0}, {"col": "Cheap", "idx": 10, "val": 244.0}, {"col": "Teleportation", "idx": 10, "val": NaN}, {"col": "Expensive", "idx": 11, "val": 368.0}, {"col": "Cheap", "idx": 11, "val": 229.0}, {"col": "Teleportation", "idx": 11, "val": NaN}, {"col": "Expensive", "idx": 12, "val": 350.0}, {"col": "Cheap", "idx": 12, "val": 215.0}, {"col": "Teleportation", "idx": 12, "val": NaN}, {"col": "Expensive", "idx": 13, "val": 327.0}, {"col": "Cheap", "idx": 13, "val": 204.0}, {"col": "Teleportation", "idx": 13, "val": NaN}, {"col": "Expensive", "idx": 14, "val": 286.0}, {"col": "Cheap", "idx": 14, "val": 224.0}, {"col": "Teleportation", "idx": 14, "val": NaN}, {"col": "Expensive", "idx": 15, "val": 274.0}, {"col": "Cheap", "idx": 15, "val": 213.0}, {"col": "Teleportation", "idx": 15, "val": NaN}, {"col": "Expensive", "idx": 16, "val": 284.0}, {"col": "Cheap", "idx": 16, "val": 186.0}, {"col": "Teleportation", "idx": 16, "val": NaN}, {"col": "Expensive", "idx": 17, "val": 279.0}, {"col": "Cheap", "idx": 17, "val": 169.0}, {"col": "Teleportation", "idx": 17, "val": NaN}, {"col": "Expensive", "idx": 18, "val": 263.0}, {"col": "Cheap", "idx": 18, "val": 159.0}, {"col": "Teleportation", "idx": 18, "val": NaN}, {"col": "Expensive", "idx": 19, "val": 241.0}, {"col": "Cheap", "idx": 19, "val": 156.0}, {"col": "Teleportation", "idx": 19, "val": NaN}, {"col": "Expensive", "idx": 20, "val": 244.0}, {"col": "Cheap", "idx": 20, "val": 130.0}, {"col": "Teleportation", "idx": 20, "val": NaN}, {"col": "Expensive", "idx": 21, "val": 223.0}, {"col": "Cheap", "idx": 21, "val": 125.0}, {"col": "Teleportation", "idx": 21, "val": NaN}, {"col": "Expensive", "idx": 22, "val": 217.0}, {"col": "Cheap", "idx": 22, "val": 116.0}, {"col": "Teleportation", "idx": 22, "val": NaN}, {"col": "Expensive", "idx": 23, "val": 192.0}, {"col": "Cheap", "idx": 23, "val": 120.0}, {"col": "Teleportation", "idx": 23, "val": NaN}, {"col": "Expensive", "idx": 24, "val": 177.0}, {"col": "Cheap", "idx": 24, "val": 118.0}, {"col": "Teleportation", "idx": 24, "val": NaN}, {"col": "Expensive", "idx": 25, "val": 163.0}, {"col": "Cheap", "idx": 25, "val": 121.0}, {"col": "Teleportation", "idx": 25, "val": NaN}, {"col": "Expensive", "idx": 26, "val": 158.0}, {"col": "Cheap", "idx": 26, "val": 112.0}, {"col": "Teleportation", "idx": 26, "val": NaN}, {"col": "Expensive", "idx": 27, "val": 158.0}, {"col": "Cheap", "idx": 27, "val": 99.0}, {"col": "Teleportation", "idx": 27, "val": NaN}, {"col": "Expensive", "idx": 28, "val": 157.0}, {"col": "Cheap", "idx": 28, "val": 90.0}, {"col": "Teleportatio ...
