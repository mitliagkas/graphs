# %%
import networkx as nx
import numpy as np
from random import randrange, choice, random
import math

# %%
import json
from networkx.readwrite import json_graph

# %% [markdown]
# # Generate graph

# %%
n = 5
m = 2
p = 0.3

# %%
G = nx.barbell_graph(5,0)

# %%
G = nx.scale_free_graph(n)

# %%
G = nx.powerlaw_cluster_graph(n=n, m=m, p=p)

# %%
G = nx.cycle_graph(5)

# %% [markdown]
# ### Save and Plot Graph

# %%
d = json_graph.node_link_data(G)
for node in d['nodes']:
    node['name']=node['id']
    node['value']=G.degree(node['id'])

d['adjacency'] = json_graph.adjacency_data(G)['adjacency']
json.dump(d, open('graph.json','w'))

# %%
# %%html
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>
# Out:
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>

# %% [markdown]
# ### Convert to DiGraph, if necessary

# %%
if G.is_multigraph():
    if G.is_directed():
        Gm = G.copy()
        G = nx.DiGraph()
        for (u,v) in Gm.edges_iter():
            G.add_edge(u,v)

# %% [markdown]
# # Simulate Random Walks

# %%
frogs = 10

# %%
# Life expectancy L. L should be the mean of a geometric distribution
L = int(math.ceil(10*math.log(G.order())))

# %%
# P_die is the probability that a frog dies at any given time
P_die = 1/float(L)

# %%
T = 10

# %% [markdown]
# #### Count Visits and Deaths

# %%
frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs)
for node in G.nodes_iter():
    G.node[node]['visits'] = 0
    G.node[node]['deaths'] = 0
# Initialize edge traversal counters
for e in G.edges_iter():
    G.edge[e[0]][e[1]]['tripsvanilla'] = 0
#    G.edge[e[0]][e[1]]['tripssmart'] = 0
#    G.edge[e[0]][e[1]]['frogswaiting'] = 0
    G.edge[e[0]][e[1]]['timeline'] = {}

# %%
P_die
# Out:
# 0.041666666666666664

# %%
frogs_left = frogs
time = 0
total_visits = 0
death_times_sum = 0
while frogs_left:
    time +=1
    for f in range(frogs):
        curloc = frog_locations[f]
        if curloc == -1:
            continue
            
        if random() < P_die:
            G.node[curloc]['deaths'] += 1
            death_times_sum += time
            frog_locations[f] = -1
            frogs_left -= 1
            continue
        
        total_visits +=1
        
        if len(G[curloc])>0:
            frog_locations[f] = choice(G[curloc].keys())
            G.edge[curloc][frog_locations[f]]['tripsvanilla'] += 1
            loc = frog_locations[f]

            try:
                G.edge[curloc][loc]['timeline'][time] += 1
            except:
                G.edge[curloc][loc]['timeline'][time] = 1
            if not G.is_directed():
                try:
                    G.edge[loc][curloc]['timeline'][time] += 1
                except:
                    G.edge[loc][curloc]['timeline'][time] = 1
        else:
            frog_locations[f] = np.random.randint(0, high = G.number_of_nodes())
            
            
        G.node[frog_locations[f]]['visits'] +=1

# %%
print "Average death time:", death_times_sum / frogs
print "Expected death time:", L
print "Nominal death time STD:", math.sqrt((1-P_die)/P_die**2)
# Out:
# Average death time: 29
# Expected death time: 24
# Nominal death time STD: 23.4946802489

# %%
visits = [G.node[node]['visits'] for node in G.nodes_iter() ]
norm_visits = np.array(visits)/float(total_visits)
norm_visits
# Out:
# array([ 0.05923345,  0.05574913,  0.07317073,  0.05226481,  0.07665505,
#         0.14285714,  0.1358885 ,  0.11149826,  0.16027875,  0.13240418])

# %%
deaths = [G.node[node]['deaths'] for node in G.nodes_iter() ]
norm_deaths = np.array(deaths)/float(frogs)
norm_deaths
# Out:
# array([ 0.2,  0. ,  0.2,  0.1,  0. ,  0. ,  0. ,  0.3,  0. ,  0.2])

# %%
if G.is_directed():
    degrees = [ G.in_degree(node) for node in G.nodes_iter() ]
    norm_degrees = np.array(degrees)/float(G.size())
else:
    degrees = [ G.degree(node) for node in G.nodes_iter() ]
    norm_degrees = np.array(degrees)/float(2*G.size())

norm_degrees
# Out:
# array([ 0.0952381 ,  0.0952381 ,  0.0952381 ,  0.0952381 ,  0.11904762,
#         0.11904762,  0.0952381 ,  0.0952381 ,  0.0952381 ,  0.0952381 ])

# %%
import vincent
vincent.initialize_notebook()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %%
multi_iter1 = {'index':range(G.order()), 'Visits':norm_visits, 'Deaths':norm_deaths, 'Degree':norm_degrees}

# %%
line = vincent.Scatter(multi_iter1, iter_idx='index')
line.axis_titles(x='Vertex', y='Juice')
line.legend(title='Results')
line.width = 400
line.height = 300
line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=1)

# %%
line.marks[0].marks[0].properties.update = vincent.PropertySet()
line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
line.marks[0].marks[0].properties.hover = vincent.PropertySet()
line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)

# %%
line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
line.marks[0].marks[0].properties.hover = vincent.PropertySet()
line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)

# %%
line.scales['shape'] = vincent.Scale(name='shape', type='ordinal',
                      domain=vincent.DataRef(data='table', field='data.col'),
                      range=["square", "circle", "triangle-down", "triangle-up"])

# %%
line.marks[0].marks[0].properties.enter.shape = vincent.ValueRef(scale="shape", field="data.col")
line.legends[0].shape = "shape"

# %%
line
# Out:
# <div id="vis0afdf1a79e984bd49af700355e44e6d8"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Vertex", "type": "x"}, {"scale": "y", "title": "Juice", "type": "y"}], "data": [{"name": "table", "values": [{"col": "Deaths", "idx": 0, "val": 0.20000000000000001}, {"col": "Deaths", "idx": 1, "val": 0.0}, {"col": "Deaths", "idx": 2, "val": 0.20000000000000001}, {"col": "Deaths", "idx": 3, "val": 0.10000000000000001}, {"col": "Deaths", "idx": 4, "val": 0.0}, {"col": "Deaths", "idx": 5, "val": 0.0}, {"col": "Deaths", "idx": 6, "val": 0.0}, {"col": "Deaths", "idx": 7, "val": 0.29999999999999999}, {"col": "Deaths", "idx": 8, "val": 0.0}, {"col": "Deaths", "idx": 9, "val": 0.20000000000000001}, {"col": "Degree", "idx": 0, "val": 0.095238095238095233}, {"col": "Degree", "idx": 1, "val": 0.095238095238095233}, {"col": "Degree", "idx": 2, "val": 0.095238095238095233}, {"col": "Degree", "idx": 3, "val": 0.095238095238095233}, {"col": "Degree", "idx": 4, "val": 0.11904761904761904}, {"col": "Degree", "idx": 5, "val": 0.11904761904761904}, {"col": "Degree", "idx": 6, "val": 0.095238095238095233}, {"col": "Degree", "idx": 7, "val": 0.095238095238095233}, {"col": "Degree", "idx": 8, "val": 0.095238095238095233}, {"col": "Degree", "idx": 9, "val": 0.095238095238095233}, {"col": "Visits", "idx": 0, "val": 0.059233449477351915}, {"col": "Visits", "idx": 1, "val": 0.055749128919860627}, {"col": "Visits", "idx": 2, "val": 0.073170731707317069}, {"col": "Visits", "idx": 3, "val": 0.052264808362369339}, {"col": "Visits", "idx": 4, "val": 0.076655052264808357}, {"col": "Visits", "idx": 5, "val": 0.14285714285714285}, {"col": "Visits", "idx": 6, "val": 0.13588850174216027}, {"col": "Visits", "idx": 7, "val": 0.11149825783972125}, {"col": "Visits", "idx": 8, "val": 0.16027874564459929}, {"col": "Visits", "idx": 9, "val": 0.13240418118466898}]}], "height": 300, "legends": [{"fill": "color", "offset": 0, "properties": {}, "shape": "shape", "title": "Results"}], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "opacity": {"value": 1}, "shape": {"field": "data.col", "scale": "shape"}, "size": {"value": 100}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "data.val", "scale": "y"}}, "hover": {"size": {"value": 200}}, "update": {"size": {"value": 100}}}, "type": "symbol"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "linear"}, {"domain": {"data": "table", "field": "data.val"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "ordinal"}, {"domain": {"data": "table", "field": "data.col"}, "name": "shape", "range": ["square", "circle", "triangle-down", "triangle-up"], "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis0afdf1a79e984bd49af700355e44e6d8"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
import pandas as pd

# %%
data = []
index = []
for e in G.edges_iter():
    key = '(' + str(e[0]) + ',' + str(e[1]) + ')'
    data.append(pd.Series(G.edge[e[0]][e[1]]['timeline']))
    index.append(key)

df = pd.DataFrame(data, index=index).T

# %%
#line = vincent.Scatter(data, iter_idx='index')
line = vincent.StackedArea(df)
line.axis_titles(x='Time', y='# frogs')
line.colors(brew = 'Spectral')
#line.axes([0, 40, 0, 2])
line.legend(title='Edge')
line.width = 400
line.height = 300
line.marks[0].marks[0].properties.enter.opacity = vincent.ValueRef(value=0.5)

# %%
line.marks[0].marks[0].properties.update = vincent.PropertySet()
line.marks[0].marks[0].properties.update.size = vincent.ValueRef(value=100)
line.marks[0].marks[0].properties.hover = vincent.PropertySet()
line.marks[0].marks[0].properties.hover.size = vincent.ValueRef(value=200)

line.marks[0].marks[0].properties.update.opacity = vincent.ValueRef(value=0.7)
line.marks[0].marks[0].properties.hover.opacity = vincent.ValueRef(value=1)

# %%
line
# Out:
# <div id="vis11520ac26a81488aa212e2f1fc8ac40a"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Time", "type": "x"}, {"scale": "y", "title": "# frogs", "type": "y"}], "data": [{"name": "table", "values": [{"col": "(0,1)", "idx": 1, "val": 2.0}, {"col": "(0,2)", "idx": 1, "val": 2.0}, {"col": "(0,3)", "idx": 1, "val": NaN}, {"col": "(0,4)", "idx": 1, "val": NaN}, {"col": "(1,2)", "idx": 1, "val": NaN}, {"col": "(1,3)", "idx": 1, "val": NaN}, {"col": "(1,4)", "idx": 1, "val": 2.0}, {"col": "(2,3)", "idx": 1, "val": NaN}, {"col": "(2,4)", "idx": 1, "val": NaN}, {"col": "(3,4)", "idx": 1, "val": NaN}, {"col": "(4,5)", "idx": 1, "val": NaN}, {"col": "(5,8)", "idx": 1, "val": 2.0}, {"col": "(5,9)", "idx": 1, "val": NaN}, {"col": "(5,6)", "idx": 1, "val": NaN}, {"col": "(5,7)", "idx": 1, "val": 4.0}, {"col": "(6,8)", "idx": 1, "val": 2.0}, {"col": "(6,9)", "idx": 1, "val": 2.0}, {"col": "(6,7)", "idx": 1, "val": 2.0}, {"col": "(7,8)", "idx": 1, "val": NaN}, {"col": "(7,9)", "idx": 1, "val": NaN}, {"col": "(8,9)", "idx": 1, "val": 2.0}, {"col": "(0,1)", "idx": 2, "val": 2.0}, {"col": "(0,2)", "idx": 2, "val": NaN}, {"col": "(0,3)", "idx": 2, "val": NaN}, {"col": "(0,4)", "idx": 2, "val": NaN}, {"col": "(1,2)", "idx": 2, "val": 2.0}, {"col": "(1,3)", "idx": 2, "val": NaN}, {"col": "(1,4)", "idx": 2, "val": NaN}, {"col": "(2,3)", "idx": 2, "val": NaN}, {"col": "(2,4)", "idx": 2, "val": NaN}, {"col": "(3,4)", "idx": 2, "val": NaN}, {"col": "(4,5)", "idx": 2, "val": 4.0}, {"col": "(5,8)", "idx": 2, "val": 4.0}, {"col": "(5,9)", "idx": 2, "val": NaN}, {"col": "(5,6)