# %%
import networkx as nx
import numpy as np
from random import randrange, choice, random
import math

# %%
import json
from networkx.readwrite import json_graph

# %% [markdown]
# # Generate graph

# %%
n = 30
m = 2
p = 0.3

# %%
G = nx.barbell_graph(10,0)

# %%
G = nx.scale_free_graph(n)

# %%
G = nx.powerlaw_cluster_graph(n=n, m=m, p=p)

# %%
G = nx.cycle_graph(10)

# %% [markdown]
# ### Save and Plot Graph

# %%
d = json_graph.node_link_data(G)
for node in d['nodes']:
    node['name']=node['id']
    node['value']=G.degree(node['id'])

d['adjacency'] = json_graph.adjacency_data(G)['adjacency']
json.dump(d, open('graph.json','w'))

# %%
# %%html
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>
# Out:
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# marker {stroke: #999;}
# .link {stroke: #999; stroke-opacity: .3;}
# </style>
# <script src="force.js"></script>

# %% [markdown]
# ### Convert to DiGraph, if necessary

# %%
if G.is_multigraph():
    if G.is_directed():
        Gm = G.copy()
        G = nx.DiGraph()
        for (u,v) in Gm.edges_iter():
            G.add_edge(u,v)

# %% [markdown]
# # Simulate Random Walks

# %%
frogs = 100

# %% [markdown]
# ## Fixed total time duration

# %%
W = 100

# %% [markdown]
# ### Count visits

# %%
frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs)
for node in G.nodes_iter():
    G.node[node]['visits'] = 0
for t in range(W):
    for f in range(frogs):
        loc = frog_locations[f]
        if len(G[loc])>0:
            frog_locations[f] = choice(G[loc].keys())
        else:
            frog_locations[f] = np.random.randint(0, high = G.number_of_nodes())
        G.node[frog_locations[f]]['visits'] +=1

# %%
fixed_visits = [G.node[node]['visits'] for node in G.nodes_iter() ]
norm_fixed_visits = np.array(fixed_visits)/float(sum(fixed_visits))
norm_fixed_visits
# Out:
# array([ 0.0499,  0.0466,  0.0461,  0.0464,  0.0471,  0.049 ,  0.0492,
#         0.044 ,  0.0455,  0.0528,  0.0542,  0.0512,  0.0566,  0.0514,
#         0.0514,  0.0534,  0.0516,  0.0508,  0.051 ,  0.0518])

# %% [markdown]
# ## Death Process

# %%
# Life expectancy L. L should be the mean of a geometric distribution
L = 100*math.log(n)
# P_die is the probability that a frog dies at any given time
P_die = 1/L

# %% [markdown]
# #### Count Visits and Deaths

# %%
frog_locations = np.random.randint(0, high = G.number_of_nodes(), size = frogs)
for node in G.nodes_iter():
    G.node[node]['visits'] = 0
    G.node[node]['deaths'] = 0
frogs_left = frogs
time = 0
total_visits = 0
death_times_sum = 0
while frogs_left:
    time +=1
    for f in range(frogs):
        if frog_locations[f] == -1:
            continue
            
        if random() < P_die:
            G.node[frog_locations[f]]['deaths'] += 1
            death_times_sum += time
            frog_locations[f] = -1
            frogs_left -= 1
            continue
        
        total_visits +=1
        
        loc = frog_locations[f]
        if len(G[loc])>0:
            frog_locations[f] = choice(G[loc].keys())
        else:
            frog_locations[f] = np.random.randint(0, high = G.number_of_nodes())
        G.node[frog_locations[f]]['visits'] +=1

# %%
print "Average death time:", death_times_sum / frogs
print "Expected death time:", L
print "Nominal death time STD:", math.sqrt((1-P_die)/P_die**2)
# Out:
# Average death time: 323
# Expected death time: 340.119738166
# Nominal death time STD: 339.619370107

# %%
visits = [G.node[node]['visits'] for node in G.nodes_iter() ]
norm_visits = np.array(visits)/float(total_visits)
norm_visits
# Out:
# array([ 0.05458156,  0.05526422,  0.05234741,  0.05169578,  0.05247153,
#         0.05225432,  0.05101313,  0.05318522,  0.05352655,  0.05821206,
#         0.05064077,  0.04604834,  0.04508642,  0.04685512,  0.04576908,
#         0.04620349,  0.04499333,  0.04669997,  0.04490024,  0.04825147])

# %%
deaths = [G.node[node]['deaths'] for node in G.nodes_iter() ]
norm_deaths = np.array(deaths)/float(frogs)
norm_deaths
# Out:
# array([ 0.05,  0.05,  0.03,  0.06,  0.04,  0.02,  0.09,  0.05,  0.1 ,
#         0.08,  0.07,  0.05,  0.03,  0.06,  0.02,  0.02,  0.03,  0.08,
#         0.03,  0.04])

# %%
if G.is_directed():
    degrees = [ G.in_degree(node) for node in G.nodes_iter() ]
    norm_degrees = np.array(degrees)/float(G.size())
else:
    degrees = [ G.degree(node) for node in G.nodes_iter() ]
    norm_degrees = np.array(degrees)/float(2*G.size())

norm_degrees
# Out:
# array([ 0.04945055,  0.04945055,  0.04945055,  0.04945055,  0.04945055,
#         0.04945055,  0.04945055,  0.04945055,  0.04945055,  0.05494505,
#         0.05494505,  0.04945055,  0.04945055,  0.04945055,  0.04945055,
#         0.04945055,  0.04945055,  0.04945055,  0.04945055,  0.04945055])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
x = np.array([norm_fixed_visits, norm_visits, norm_deaths, norm_degrees]).T

plt.plot(np.array(range(G.order())).T,x)
plt.legend(['Visits (Fixed Time)', 'Visits', 'Deaths', 'Degree'], loc='best')
plt.axis([0, G.order()-1, 0, min([2*np.max(x),1])]);

# %%
import vincent

# %%
vincent.initialize_notebook()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %%
multi_iter1 = {'index':range(G.order()), 'visits_fixed':norm_fixed_visits, 'visits':norm_visits, 'deaths':norm_deaths, 'degrees':norm_degrees}

# %%
line = vincent.Line(multi_iter1, iter_idx='index')
line.axis_titles(x='Index', y='Value')
line.legend(title='Results')
line.width = 400
line.height = 300
line.colors(range_=['#a6cee3','#1f78b4','#b2df8a','#33a02c'])
line.colors(brew='Paired')
line.marks[0].marks[0].properties.enter.stroke_width.value = 6
line.marks[0].marks[0].properties.enter.stroke_opacity = vincent.ValueRef(value=0.7)

# %%
line.marks[0].marks[0].properties.update = vincent.PropertySet()
line.marks[0].marks[0].properties.update.stroke_opacity = vincent.ValueRef(value=0.7)
line.marks[0].marks[0].properties.hover = vincent.PropertySet()
line.marks[0].marks[0].properties.hover.stroke_opacity = vincent.ValueRef(value=1)

# %%
line
# Out:
# <div id="vis86da01cd186a4090901b76de7b25be6d"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Index", "type": "x"}, {"scale": "y", "title": "Value", "type": "y"}], "data": [{"name": "table", "values": [{"col": "deaths", "idx": 0, "val": 0.050000000000000003}, {"col": "deaths", "idx": 1, "val": 0.050000000000000003}, {"col": "deaths", "idx": 2, "val": 0.029999999999999999}, {"col": "deaths", "idx": 3, "val": 0.059999999999999998}, {"col": "deaths", "idx": 4, "val": 0.040000000000000001}, {"col": "deaths", "idx": 5, "val": 0.02}, {"col": "deaths", "idx": 6, "val": 0.089999999999999997}, {"col": "deaths", "idx": 7, "val": 0.050000000000000003}, {"col": "deaths", "idx": 8, "val": 0.10000000000000001}, {"col": "deaths", "idx": 9, "val": 0.080000000000000002}, {"col": "deaths", "idx": 10, "val": 0.070000000000000007}, {"col": "deaths", "idx": 11, "val": 0.050000000000000003}, {"col": "deaths", "idx": 12, "val": 0.029999999999999999}, {"col": "deaths", "idx": 13, "val": 0.059999999999999998}, {"col": "deaths", "idx": 14, "val": 0.02}, {"col": "deaths", "idx": 15, "val": 0.02}, {"col": "deaths", "idx": 16, "val": 0.029999999999999999}, {"col": "deaths", "idx": 17, "val": 0.080000000000000002}, {"col": "deaths", "idx": 18, "val": 0.029999999999999999}, {"col": "deaths", "idx": 19, "val": 0.040000000000000001}, {"col": "degrees", "idx": 0, "val": 0.049450549450549448}, {"col": "degrees", "idx": 1, "val": 0.049450549450549448}, {"col": "degrees", "idx": 2, "val": 0.049450549450549448}, {"col": "degrees", "idx": 3, "val": 0.049450549450549448}, {"col": "degrees", "idx": 4, "val": 0.049450549450549448}, {"col": "degrees", "idx": 5, "val": 0.049450549450549448}, {"col": "degrees", "idx": 6, "val": 0.049450549450549448}, {"col": "degrees", "idx": 7, "val": 0.049450549450549448}, {"col": "degrees", "idx": 8, "val": 0.049450549450549448}, {"col": "degrees", "idx": 9, "val": 0.054945054945054944}, {"col": "degrees", "idx": 10, "val": 0.054945054945054944}, {"col": "degrees", "idx": 11, "val": 0.049450549450549448}, {"col": "degrees", "idx": 12, "val": 0.049450549450549448}, {"col": "degrees", "idx": 13, "val": 0.049450549450549448}, {"col": "degrees", "idx": 14, "val": 0.049450549450549448}, {"col": "degrees", "idx": 15, "val": 0.049450549450549448}, {"col": "degrees", "idx": 16, "val": 0.049450549450549448}, {"col": "degrees", "idx": 17, "val": 0.049450549450549448}, {"col": "degrees", "idx": 18, "val": 0.049450549450549448}, {"col": "degrees", "idx": 19, "val": 0.049450549450549448}, {"col": "visits", "idx": 0, "val": 0.054581562044248612}, {"col": "visits", "idx": 1, "val": 0.055264219443323923}, {"col": "visits", "idx": 2, "val": 0.052347410556365777}, {"col": "visits", "idx": 3, "val": 0.05169578303906662}, {"col": "visits", "idx": 4, "val": 0.052471530083470379}, {"col": "visits", "idx": 5, "val": 0.052254320911037329}, {"col": "visits", "idx": 6, "val": 0.051013125639991309}, {"col": "visits", "idx": 7, "val": 0.053185217364321843}, {"col": "visits", "idx": 8, "val": 0.053526546063859495}, {"col": "visits", "idx": 9, "val": 0.058212058212058215}, {"col": "visits", "idx": 10, "val": 0.050640767058677504}, {"col": "visits", "idx": 11, "val": 0.046048344555807245}, {"col": "visits", "idx": 12, "val": 0.045086418220746577}, {"col": "visits", "idx": 13, "val": 0.046855121481987151}, {"col": "visits", "idx": 14, "val": 0.045769075619821888}, {"col": "visits", "idx": 15, "val": 0.046203493964687994}, {"col": "visits", "idx": 16, "val": 0.044993328575418129}, {"col": "visits", "idx": 17, "val": 0.046699972073106402}, {"col": "visits", "idx": 18, "val": 0.044900238930089674}, {"col": "visits", "idx": 19, "val": 0.048251466161913927}, {"col": "visits_fixed", "idx": 0, "val": 0.0499}, {"col": "visits_fixed", "idx": 1, "val": 0.046600000000000003}, {"col": "visits_fixed", "idx": 2, "val": 0.046100000000000002}, {"col": "visits_fixed", "idx": 3, "val": 0.046399999999999997}, {"col": "visits_fixed", "idx": 4, "val": 0.047100000000000003}, {"col": "visits_fixed", "idx": 5, "val": 0.0490000 ...
#          chart({el: "#vis86da01cd186a4090901b76de7b25be6d"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %% [markdown]
#     "update": {
#       "fill": {"value": "steelblue"}
#     },
#     "hover": {
#       "fill": {"value": "red"}
#     }

# %%
mrk.key

# %%
line.marks[0].properties.update.fill.value = 'red'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-192-7b77dc11c607> in <module>()
# ----> 1 line.marks[0].properties.update.fill.value = 'red'
#
# AttributeError: 'NoneType' object has no attribute 'update'

# %%
line.marks[0].marks[0].properties.enter.grammar()
# Out:
# {u'stroke': {u'field': u'data.col', u'scale': u'color'},
#  u'strokeWidth': {u'value': 2},
#  u'x': {u'field': u'data.idx', u'scale': u'x'},
#  u'y': {u'field': u'data.val', u'scale': u'y'}}

# %%
ps = line.marks[0].marks[0].properties.enter
ps.stroke_width.value = 7
ps.stroke_opacity = vincent.ValueRef(value=0.5)

# %%
ps.grammar()
# Out:
# {u'stroke': {u'field': u'data.col', u'scale': u'color'},
#  u'strokeWidth': {u'value': 7},
#  u'x': {u'field': u'data.idx', u'scale': u'x'},
#  u'y': {u'field': u'data.val', u'scale': u'y'}}

# %%
>>>vis.marks[0].properties.enter.y2.scale = 1
